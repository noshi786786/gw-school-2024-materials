# %% [markdown]
# # Import Useful Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from enterprise.pulsar import Pulsar
from enterprise_extensions import blocks
import pickle
import NimaClass as nc
from astropy.coordinates import SkyCoord
from astropy import units as u
from enterprise.signals import gp_signals, signal_base
from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc
from enterprise_extensions import sampler as samp
import sim
import corner
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Plotting Settings

# %% [markdown]
# Note: If you do not like a dark_background for your plots, do not run `plt.style.use('dark_background')`

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('dark_background')
hist_settings = dict(
    bins = 40,
    histtype = 'step',
    lw = 3,
    density = True
)

# %% [markdown]
# # <center><span style="color:#7cfc00">Introduction

# %% [markdown]
# The goal of detection is to assess the statistical significance of various types of <span style="color:red">red noise processes</span>. To achieve this goal, we need to make sure we understand a few topics defined within the context of pulsar timing experiments.

# %% [markdown]
# ## <span style="color:#7cfc00">Topic 1: What is a noise process?

# %% [markdown]
# A noise process is a series of random numbers which are completely independent of each other. This means you cannot predict the future given the past, in complete contrast to deterministic processes.

# %% [markdown]
# We deal with two types of noise processes:
# 1. White (Gaussian) Noise: random numbers drawn from a Gaussian distribution with the property that their spectral power is constant across all frequencies.
# 2. Red Noise: a linear combination of white noise processes filtered in a way that its spectral power decreases with increasing frequencies.
#
# In case you are not familiar with spectral power, you can think of it as a measure of the strength of the signal that the series of random numbers represent. This power is defined in the frequency domain. It is an extremely important quantity!

# %% [markdown]
# ### <span style="color:#7cfc00">White Noise

# %% [markdown]
# $\Large w_{\underbrace{I}_{\text{pulsar index}}}$

# %%
draws = int(1e6)
wn = np.random.normal(loc = 0, scale = .2, size = draws)
t = np.linspace(0, 5400, draws)

idxs = np.random.randint(0, draws, 500)
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (6*2, 6))
ax[0].hist(wn, **hist_settings)
ax[0].set_title('White Noise -- Probability Distribution')
ax[1].scatter(t[idxs], wn[idxs])
ax[1].set_title('White Noise -- The Process')
ax[0].set_xlabel('White Noise values')
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Density')
ax[1].set_ylabel('White Noise values')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <span style="color:#7cfc00">Red Noise
# $\Large r_I(f) = c_I(f)w_I(f)$

# %% [markdown]
# $\Large {\underbrace{c_I}_{\text{filtering function that sets the spectral power}}}$

# %%
rn = np.load('../Data/red_noise_example.npz')['rn']
t = np.linspace(0, 100, len(rn))

fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (6*2, 6))
ax[0].hist(rn, **hist_settings)
ax[0].set_title('Red Noise -- Probability Distribution')
ax[1].scatter(t, rn)
ax[1].set_title('Red Noise -- The Process')
ax[0].set_xlabel('Red Noise values')
ax[1].set_xlabel('Time')
ax[0].set_ylabel('Density')
ax[1].set_xlabel('Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <span style="color:#7cfc00">Note:

# %% [markdown]
# 1. When dealing with noise, the concept of <span style="color:red">realization</span> becomes important. One can construct infinite number of unique-looking signals in the time-domain all of which possessing the same spectral properties (e.g., identical spectral power). A realization of a noise process is one out of infinite number of such possibilities. When doing computation, changing the seed of a random number generator changes the realization of the noise process made out of the random numbers.

# %% [markdown]
# 2. The mean of a red noise process is not zero, unlike a white noise process, if you take the mean over a single realization. In theory, a true red noise process is a zero-mean process if the mean is taken over many realizations. Make sure you understand the difference between them!

# %% [markdown]
# ## <span style="color:#7cfc00">Topic 2: What is a common red noise process?
# $\Large r_I(f) = c(f)w_I(f)$

# %% [markdown]
# Definition: If different realizations of the same red noise process exist between different pulsars' timing residuals, the process is called a common red noise process.

# %% [markdown]
# Question: How to go about checking if multiple realizations of the same red noise process exist in different pulsars? What statistical quantity could reveal such information?

# %% [markdown]
# Note: note the difference between how $r_I$ is defined as a common red noise versus as a red noise.

# %% [markdown]
# ## <span style="color:#7cfc00"> Topic 3: What is a common correlated red noise process?

# %% [markdown]
# $\Large r_I(f) = c(f)\sum_{J}\Gamma_{IJ}w_J(f)$

# %% [markdown]
# $\Large {\underbrace{\Gamma_{IJ}}_{\text{a non-diagonal matrix}}}$

# %% [markdown]
# Definition: if a pair of two different realizations of the same red noise process are correlated, the red noise process between the pair is called a common correlated red noise process.

# %% [markdown]
# If the non-diagonal elements of the matrix $\large \Gamma$ depend on pulsar pairs' angular separation, the correlation is called spatial correlation. This type of correlation is searched for in PTA GWB analyses.

# %% [markdown]
# ## <span style="color:#7cfc00">Topic 4: What is an intrinsic red noise process?

# %% [markdown]
# Definition: a red noise process that is not common between pulsars

# %% [markdown]
# ## <span style="color:#7cfc00">Topic 5: What is spectral power?

# %% [markdown]
# Spectral power, power spectral density, and PSD all refer to the same quantity. As described earlier, PSD is a measure of a noise process's strength defined in the frequency domain. Mathematically,

# %% [markdown]
# $\Large \langle r_I(f)r_I^*(f')\rangle  = \delta(f-f') \times \text{PSD} $,

# %% [markdown]
# where $\delta$ is the kronecker delta function.

# %% [markdown]
# You can model a red noise's PSD in any shape you want as long as the value of PSD decreases with increasing frequency. The two simplest and the most used models are
# 1. Powerlaw model
#
# 2. Free spectral model
# The choice for the way you model PSD of a red noise process could be astrophysically motivated. You will hear about this in future tutorials!

# %% [markdown]
# ### <span style="color:#7cfc00">Powerlaw Model of PSD

# %% [markdown]
# $\Large P(f_k) = \frac{A^2}{12 \pi^2 f_k^3} \left( \frac{f_k}{f_{\text{ref}}}\right)^{3-\gamma},$

# %% [markdown]
# $k$ is the frequency index, $A$ is the amplitude, $f_\text{ref}$ is the reference frequency (typically 1/1yr), and $\gamma$ is the spectral index which must be a positive number.

# %% [markdown]
# ### <span style="color:#7cfc00">Free-spectral Model of PSD

# %% [markdown]
# $\Large P(f_k) = T_{\text{obs}}\rho_k^2$

# %% [markdown]
# $T_{\text{obs}}$ is the observational time and $\rho_k^2$ is the value of PSD at frequency-bin $k$. Notice the difference between a powerlaw model and a free-spectral model. In a free-spectral model, each frequency-bin is allowed to have its own PSD independent of other bins.

# %% [markdown]
# # <center><span style="color:#7cfc00">ENTERPRISE: a PTA Data Analysis Tool

# %% [markdown]
# ![title](../Image/ENTERPRISE.png)

# %% [markdown]
# ## <span style="color:#7cfc00"> Input

# %%
##The ENTERPRISE python object holding information from par & tim files
psrs = []

# %% [markdown]
# ### <span style="color:#7cfc00"> In case you have par & tim files:

# %%
# # Path to tim file(s)
# timfiles = sorted(glob.glob('...' + '/*.tim'))
# # Path to par file(s)
# parfiles = sorted(glob.glob('...'+ '/*.par'))
# for p, t in zip(parfiles, timfiles):
#     psrs.append(Pulsar(p, t, ephem = None , clk=None))

# %% [markdown]
# ### <span style="color:#7cfc00"> In case you have a pickle file of the psrs object

# %%
with open('../Data/Pickle/0.pkl', 'rb') as fin:
    psrs = pickle.load(fin)
psrs
# Out:
# [<enterprise.pulsar.Tempo2Pulsar at 0x7fced8704820>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3d30>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3ac0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb39a0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb38b0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3be0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3eb0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3d90>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3f70>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3e50>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffb3a00>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc80a0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc8130>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc81c0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc86d0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc8be0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc90f0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc9600>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffc9b10>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffca020>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffca530>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffcaa40>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffcaf50>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffcb460>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffcb970>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffcbe80>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffd83d0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffd88e0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffd8df0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffd9300>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffd9810>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffd9d20>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffda230>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffda740>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffdac50>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffdb160>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffdb670>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffdbb80>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe80d0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe83a0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe88b0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe8dc0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe92d0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe97e0>,
#  <enterprise.pulsar.Tempo2Pulsar at 0x7fcd1ffe9cf0>]

# %% [markdown]
# ## <span style="color:#7cfc00"> Exploring the `psrs` object

# %%
## all the atributes of the psrs object
dir(psrs[0])
# Out:
# ['Mmat',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_decj',
#  '_deflated',
#  '_designmatrix',
#  '_dm',
#  '_flags',
#  '_get_pdist',
#  '_get_planetssb',
#  '_get_pos',
#  '_get_radec',
#  '_get_radec_from_ecliptic',
#  '_get_sunssb',
#  '_iisort',
#  '_isort',
#  '_pdist',
#  '_planetssb',
#  '_pos',
#  '_pos_t',
#  '_raj',
#  '_residuals',
#  '_set_dm',
#  '_sort',
#  '_ssbfreqs',
#  '_stoas',
#  '_sunssb',
#  '_telescope',
#  '_toaerrs',
#  '_toas',
#  '_todeflate',
#  'backend_flags',
#  'deflate',
#  'destroy',
#  'dm',
#  'dmx',
#  'filter_data',
#  'fitpars',
#  'flags',
#  'freqs',
#  'iisort',
#  'inflate',
#  'isort',
#  'name',
#  'pdist',
#  'phi',
#  'planets',
#  'planetssb',
#  'pos',
#  'pos_t',
#  'residuals',
#  'set_flags',
#  'setpars',
#  'sort_data',
#  'stoas',
#  'sunssb',
#  'telescope',
#  'theta',
#  'to_pickle',
#  'toaerrs',
#  'toas']

# %%
## number of pulsars
Npulsars = len(psrs)
Npulsars
# Out:
# 45

# %%
## name of the pulsars
psrlist = [psr.name for psr in psrs]
psrlist
# Out:
# ['B1855+09',
#  'B1937+21',
#  'B1953+29',
#  'J0023+0923',
#  'J0030+0451',
#  'J0340+4130',
#  'J0613-0200',
#  'J0636+5128',
#  'J0645+5158',
#  'J0740+6620',
#  'J0931-1902',
#  'J1012+5307',
#  'J1024-0719',
#  'J1125+7819',
#  'J1453+1902',
#  'J1455-3330',
#  'J1600-3053',
#  'J1614-2230',
#  'J1640+2224',
#  'J1643-1224',
#  'J1713+0747',
#  'J1738+0333',
#  'J1741+1351',
#  'J1744-1134',
#  'J1747-4036',
#  'J1832-0836',
#  'J1853+1303',
#  'J1903+0327',
#  'J1909-3744',
#  'J1910+1256',
#  'J1911+1347',
#  'J1918-0642',
#  'J1923+2515',
#  'J1944+0907',
#  'J2010-1323',
#  'J2017+0603',
#  'J2033+1734',
#  'J2043+1711',
#  'J2145-0750',
#  'J2214+3000',
#  'J2229+2643',
#  'J2234+0611',
#  'J2234+0944',
#  'J2302+4442',
#  'J2317+1439']

# %%
## toas and residuals
for psr in psrs[:5]:
    plt.plot(psr.toas/(86400), psr.residuals)
    plt.title(psr.name)
    plt.xlabel('TOAs [MJD]')
    plt.ylabel('Timing Residuals (s)')
    plt.tight_layout()
    plt.show()

# %%
## pulsars' sky location
dec = np.array([psr._decj for psr in psrs])
ra = np.array([psr._raj for psr in psrs])

# %%
sc = SkyCoord(ra = ra , dec = dec, unit = 'rad', frame='icrs')
plt.figure(figsize=(12, 6))
plt.subplot(projection="aitoff")

c = SkyCoord(ra*180/np.pi, dec*180/np.pi, unit = 'deg', frame='icrs')
ra_rad = c.ra.wrap_at(180 * u.deg).radian
dec_rad = c.dec.radian
plt.scatter(ra_rad  , dec_rad,marker=(5, 2),color = 'r',label = 'Pulsars')

plt.xticks(ticks=np.radians([-150, -120, -90, -60, -30, 0, \
                                30, 60, 90, 120, 150]),
            labels=['10h', '8h', '6h', '4h', '2h', '0h', \
                    '22h', '20h', '18h', '16h', '14h'])

plt.xlabel('Right Ascension in hours')
plt.ylabel('Declination in deg.')
plt.grid(True)
plt.legend(loc = 'upper right')
plt.tight_layout()
plt.show()

# %%
## Pulsar distances and their error (mean, std)
[psr.pdist for psr in psrs]
# Out:
# [(0.9, 0.2),
#  (5.0, 2.0),
#  (5.39, 1.1),
#  (1.0, 0.2),
#  (0.28, 0.1),
#  (1.0, 0.2),
#  (0.9, 0.4),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (0.7, 0.2),
#  (0.49, 0.12),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (0.74, 0.15),
#  (2.4, 0.9),
#  (1.0, 0.2),
#  (1.19, 0.238),
#  (0.42, 0.09),
#  (1.05, 0.06),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (0.42, 0.02),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.26, 0.03),
#  (1.95, 0.39),
#  (1.0, 0.2),
#  (1.4, 0.28),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (0.57, 0.11),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.0, 0.2),
#  (1.89, 0.38)]

# %%
## TOA errors in seconds
[psr.toaerrs for psr in psrs]
# Out:
# [array([8.21180e-07, 1.77930e-07, 1.98610e-07, 8.17000e-07, 8.19210e-07,
#         8.16030e-07, 6.15920e-07, 8.67430e-07, 9.15560e-07, 3.87070e-07,
#         1.93410e-07, 1.66100e-07, 9.67300e-08, 1.17030e-07, 2.72350e-07,
#         1.27240e-07, 2.61260e-07, 1.60860e-07, 2.43280e-07, 3.62650e-07,
#         2.42530e-07, 2.80290e-07, 1.17170e-07, 8.14050e-07, 1.96110e-07,
#         8.76040e-07, 2.60310e-07, 2.22550e-07, 4.51440e-07, 3.56940e-07,
#         3.42390e-07, 2.23210e-07, 1.81390e-07, 8.24830e-07, 9.36700e-07,
#         8.40170e-07, 8.30260e-07, 8.71800e-07, 1.00416e-06, 8.41990e-07,
#         1.12316e-06, 8.24110e-07, 8.83800e-07, 8.49580e-07, 8.88990e-07,
#         8.72980e-07, 8.82150e-07, 5.71790e-07, 2.96450e-07, 4.25350e-07,
#         2.02890e-07, 2.19879e-06, 2.19556e-06, 2.40390e-07, 2.32810e-07,
#         2.69830e-07, 2.34080e-07, 2.34990e-07, 2.38760e-07, 2.43410e-07,
#         2.19659e-06, 2.46110e-07, 2.46820e-07, 2.19857e-06, 2.28090e-07,
#         2.19621e-06, 2.19641e-06, 2.33930e-07, 2.28640e-07, 2.19678e-06,
#         2.19582e-06, 2.19411e-06, 2.39970e-07, 2.19475e-06, 2.45020e-07,
#         2.19586e-06, 2.19643e-06, 2.19393e-06, 2.19453e-06, 2.19500e-06,
#         2.19605e-06, 2.52560e-07, 2.19416e-06, 2.19426e-06, 2.19405e-06,
#         2.19693e-06, 2.19420e-06, 2.19435e-06, 2.19577e-06, 2.82020e-07,
#         3.19810e-07, 2.78020e-07, 2.31610e-07, 2.36400e-07, 2.31190e-07,
#         2.41420e-07, 2.56970e-07, 2.41190e-07, 2.37410e-07, 2.33760e-07,
#         2.32890e-07, 2.49630e-07, 2.46460e-07, 2.43270e-07, 2.20385e-06,
#         2.19727e-06, 2.19540e-06, 2.19476e-06, 2.19668e-06, 2.19566e-06,
#         2.19473e-06, 2.19594e-06, 2.19614e-06, 2.19493e-06, 2.19434e-06,
#         2.19397e-06, 2.19466e-06, 2.19507e-06, 2.19767e-06, 2.19620e-06,
#         2.19514e-06, 2.20113e-06, 2.19711e-06, 2.19443e-06, 2.19437e-06,
#         2.19629e-06, 2.19531e-06, 2.19433e-06, 2.19467e-06, 2.19639e-06,
#         2.19697e-06, 2.19647e-06, 2.19455e-06, 2.19472e-06, 2.19512e-06,
#         2.19479e-06, 2.19487e-06, 2.19446e-06, 2.19502e-06, 2.19545e-06,
#         2.19444e-06, 2.19551e-06, 2.19645e-06, 2.19435e-06, 2.19484e-06,
#         2.20079e-06, 2.19646e-06, 2.19627e-06, 2.19447e-06, 2.19436e-06,
#         2.19450e-06, 2.19479e-06, 2.19421e-06, 2.19435e-06, 2.19430e-06,
#         2.19579e-06, 2.19478e-06, 2.19516e-06, 2.20100e-06, 2.19601e-06,
#         2.19490e-06, 2.19492e-06, 2.19594e-06, 2.19454e-06, 2.19461e-06,
#         2.19758e-06, 2.19638e-06, 2.19705e-06, 2.19475e-06, 2.19517e-06,
#         2.19696e-06, 2.19529e-06, 2.19755e-06, 2.19502e-06, 2.19438e-06,
#         2.19709e-06, 2.19481e-06, 2.19450e-06, 2.19533e-06, 2.19533e-06,
#         2.19409e-06, 2.19567e-06, 2.19507e-06, 2.19561e-06, 2.19785e-06,
#         2.19481e-06, 2.19705e-06, 2.20088e-06, 2.19528e-06, 2.19494e-06,
#         2.19600e-06, 2.19539e-06, 2.19641e-06, 2.19621e-06, 2.19699e-06,
#         2.19488e-06, 2.19624e-06, 2.19599e-06, 2.19404e-06, 2.19600e-06,
#         2.19768e-06, 2.19575e-06, 2.19465e-06, 2.19454e-06, 2.20078e-06,
#         2.19782e-06, 2.19491e-06, 2.19639e-06, 2.19431e-06, 2.19514e-06,
#         2.19600e-06, 2.19433e-06, 2.19413e-06, 2.19496e-06, 2.19441e-06,
#         2.20109e-06, 2.19643e-06, 2.19552e-06, 2.19632e-06]),
#  array([1.13660e-07, 5.95400e-08, 1.15670e-07, 7.88900e-08, 4.49400e-08,
#         1.18000e-07, 1.14460e-07, 2.81870e-07, 8.37200e-08, 1.16720e-07,
#         1.29270e-07, 6.98000e-08, 1.21100e-07, 1.23100e-07, 5.53000e-08,
#         7.69000e-08, 1.15980e-07, 4.68000e-08, 1.13830e-07, 1.15720e-07,
#         1.15320e-07, 8.28500e-08, 1.14060e-07, 7.96800e-08, 1.17240e-07,
#         2.84800e-07, 1.16240e-07, 1.18080e-07, 1.20120e-07, 1.18620e-07,
#         7.67800e-08, 1.19880e-07, 6.91200e-08, 2.85900e-08, 1.19940e-07,
#         1.16040e-07, 6.61000e-08, 3.63600e-08, 1.16800e-07, 1.26160e-07,
#         3.94900e-08, 1.20880e-07, 4.21400e-08, 1.14110e-07, 6.66300e-08,
#         1.13460e-07, 7.19500e-08, 1.21650e-07, 3.62800e-08, 3.13700e-08,
#         1.16980e-07, 1.15950e-07, 1.12870e-07, 1.27270e-07, 4.38900e-08,
#         1.17950e-07, 1.16760e-07, 5.53600e-08, 1.20020e-07, 5.44200e-08,
#         1.18570e-07, 1.16760e-07, 6.38400e-08, 5.88800e-08, 1.13740e-07,
#         1.20980e-07, 1.53100e-07, 1.37020e-07, 6.50900e-08, 6.13100e-08,
#         1.15500e-07, 1.19700e-07, 1.18250e-07, 6.60800e-08, 8.31700e-08,
#         6.28600e-08, 1.15540e-07, 1.20230e-07, 3.47200e-08, 1.18950e-07,
#         4.04700e-08, 1.20500e-07, 2.80370e-07, 6.40900e-08, 1.16270e-07,
#         1.25620e-07, 1.01350e-07, 1.18190e-07, 8.28900e-08, 1.18580e-07,
#         8.31100e-08, 2.84540e-07, 1.15370e-07, 7.88200e-08, 8.08900e-08,
#         1.17060e-07, 1.34370e-07, 3.63300e-07, 1.34520e-07, 3.63950e-07,
#         1.34970e-07, 9.18300e-08, 2.86720e-07, 3.63260e-07, 1.34390e-07,
#         1.16960e-07, 3.64170e-07, 1.34070e-07, 3.63110e-07, 1.34330e-07,
#         1.34350e-07, 1.34140e-07, 1.23820e-07, 1.34730e-07, 3.61180e-07,
#         1.34540e-07, 1.34630e-07, 3.64260e-07, 1.34180e-07, 3.63030e-07,
#         2.84160e-07, 1.34650e-07, 1.25130e-07, 3.67110e-07, 1.34420e-07,
#         1.23160e-07, 2.82630e-07, 3.64020e-07, 1.34790e-07, 2.82070e-07,
#         2.81410e-07, 2.80960e-07, 1.35300e-07, 1.21610e-07, 1.34430e-07,
#         1.22060e-07, 1.34270e-07, 2.81380e-07, 3.61350e-07, 2.82720e-07,
#         1.30040e-07, 3.62950e-07, 1.34250e-07, 1.35980e-07, 1.34570e-07,
#         3.63820e-07, 1.35960e-07, 1.34780e-07, 3.63210e-07, 3.62980e-07,
#         1.34450e-07, 9.21500e-08, 3.64330e-07, 1.34410e-07, 1.36000e-07,
#         1.34500e-07, 3.63590e-07, 1.33950e-07, 3.63260e-07, 3.62850e-07,
#         1.34290e-07, 1.36090e-07, 3.61190e-07, 3.61170e-07, 3.61180e-07,
#         1.35890e-07, 1.34210e-07, 3.62900e-07, 1.34480e-07, 9.24800e-08,
#         1.34290e-07, 3.63090e-07, 1.35920e-07, 1.34210e-07, 3.62950e-07,
#         1.36040e-07, 1.35100e-07, 3.63230e-07, 1.34740e-07, 9.23800e-08,
#         3.63560e-07, 1.34280e-07, 9.25000e-08, 3.63350e-07, 1.34600e-07,
#         1.35850e-07, 3.63090e-07, 1.34350e-07, 3.63180e-07, 1.34220e-07,
#         1.35830e-07, 3.61170e-07, 1.34260e-07, 3.62070e-07, 1.34270e-07,
#         1.35890e-07, 1.38150e-07, 1.33980e-07, 1.35670e-07, 1.35940e-07,
#         1.34110e-07, 3.63330e-07, 1.37590e-07, 1.34290e-07, 1.35840e-07,
#         1.35900e-07, 3.63200e-07, 1.34270e-07, 1.36000e-07, 1.34610e-07,
#         1.36860e-07, 3.63540e-07, 3.64300e-07, 1.38690e-07, 1.34480e-07,
#         3.63670e-07, 1.34600e-07, 3.62740e-07, 1.34650e-07, 1.36030e-07,
#         1.34350e-07, 3.63520e-07, 3.63210e-07, 3.63500e-07, 3.63230e-07,
#         1.34340e-07, 1.36120e-07, 1.34330e-07, 3.63200e-07, 1.67770e-07,
#         3.61190e-07, 1.34410e-07, 3.63220e-07, 1.31696e-06, 3.63230e-07,
#         1.34360e-07, 1.37390e-07, 1.34310e-07, 3.62860e-07, 1.36170e-07,
#         1.34500e-07, 3.62970e-07, 1.36110e-07, 3.62780e-07, 1.34260e-07,
#         1.36010e-07, 3.61180e-07, 1.35980e-07, 3.63510e-07, 1.34410e-07,
#         1.36130e-07, 1.34200e-07, 1.36310e-07, 1.34640e-07, 1.36140e-07,
#         1.34470e-07, 1.35980e-07, 1.34170e-07, 3.63520e-07, 1.36300e-07,
#         1.34370e-07, 3.63340e-07, 1.35960e-07, 1.34280e-07, 3.63130e-07,
#         9.21800e-08, 1.34000e-07, 1.34540e-07, 1.33960e-07, 3.63510e-07,
#         3.63720e-07, 9.23400e-08, 3.63880e-07, 1.35030e-07, 9.21700e-08,
#         3.63530e-07, 1.34580e-07, 9.22500e-08, 9.19100e-08, 9.23100e-08,
#         1.34330e-07, 3.63540e-07, 9.22700e-08, 9.24300e-08, 3.63400e-07,
#         1.34260e-07, 9.23000e-08, 1.34840e-07, 9.29400e-08, 1.34370e-07,
#         9.22800e-08, 1.34110e-07, 3.63750e-07, 9.26800e-08, 3.61260e-07,
#         9.22800e-08, 9.27400e-08, 1.35180e-07, 9.25400e-08, 9.21400e-08,
#         3.61250e-07, 9.23700e-08, 1.34390e-07, 9.22200e-08, 9.22200e-08,
#         9.22900e-08, 3.63710e-07, 1.34400e-07, 9.24200e-08, 1.34370e-07,
#         3.63630e-07, 9.22300e-08, 9.26000e-08, 9.65800e-08, 9.54000e-08,
#         3.58760e-07, 9.76000e-08, 9.64000e-08, 9.35500e-08, 1.34190e-07,
#         9.25900e-08, 1.31080e-07, 9.46400e-08, 9.70900e-08, 1.36240e-07,
#         9.29200e-08, 3.40310e-07, 3.40430e-07, 9.50400e-08, 3.40630e-07,
#         3.42350e-07, 3.63380e-07, 9.71800e-08, 9.56100e-08, 9.31500e-08,
#         9.21400e-08, 9.30500e-08, 3.43060e-07, 9.38600e-08, 1.36200e-07,
#         9.81000e-08, 3.48810e-07, 9.22300e-08, 9.80300e-08, 3.59950e-07,
#         9.36900e-08, 1.29650e-07, 3.61300e-07, 9.80900e-08, 3.46440e-07,
#         9.49400e-08, 3.47800e-07, 9.33300e-08, 9.59200e-08, 3.41560e-07,
#         1.30750e-07, 3.50010e-07, 9.65800e-08, 9.21600e-08, 1.36980e-07,
#         9.74200e-08, 9.77400e-08, 1.37100e-07, 9.64500e-08, 9.34100e-08,
#         9.47200e-08, 9.81100e-08, 1.38660e-07, 3.60310e-07, 9.84100e-08,
#         1.33910e-07, 1.33530e-07, 9.32000e-08, 9.20200e-08, 9.42000e-08,
#         9.72400e-08, 9.38800e-08, 9.25900e-08, 1.33320e-07, 1.36810e-07,
#         1.34440e-07, 1.30710e-07, 1.35420e-07, 3.46320e-07, 9.64000e-08,
#         1.35630e-07, 9.60500e-08, 3.41760e-07, 3.54170e-07, 9.32300e-08,
#         9.53000e-08, 9.30600e-08, 9.64200e-08, 9.68000e-08, 9.63600e-08,
#         3.43400e-07, 9.55000e-08, 9.40900e-08, 3.48910e-07, 9.31300e-08,
#         3.39610e-07, 9.77000e-08, 9.48500e-08, 1.37550e-07, 3.40540e-07,
#         1.38760e-07, 3.53350e-07, 9.33600e-08, 9.46800e-08, 3.52860e-07,
#         9.47300e-08, 9.84000e-08, 9.38500e-08, 9.81700e-08, 9.68800e-08,
#         9.51300e-08, 9.33200e-08, 9.19100e-08, 3.61330e-07, 9.19900e-08,
#         9.29600e-08, 9.76500e-08, 9.58000e-08, 9.55400e-08, 1.35550e-07,
#         9.49600e-08, 1.30110e-07, 1.37970e-07, 9.30900e-08, 9.51200e-08,
#         9.42500e-08, 9.22700e-08, 9.72800e-08, 3.43920e-07, 1.31360e-07,
#         9.66700e-08, 1.33270e-07, 3.46830e-07, 1.31330e-07, 9.53900e-08,
#         9.31600e-08, 1.37100e-07, 3.41970e-07, 1.31520e-07, 9.58100e-08,
#         3.43070e-07, 9.25200e-08, 9.76800e-08, 9.79000e-08, 9.84300e-08,
#         1.37670e-07, 9.74300e-08, 9.37300e-08, 9.79700e-08, 9.45000e-08,
#         1.36110e-07, 1.33550e-07, 9.74200e-08, 3.41690e-07, 9.66000e-08,
#         3.52240e-07, 9.42700e-08, 9.37000e-08, 1.29650e-07, 3.63200e-07,
#         9.37300e-08, 9.52700e-08, 9.64200e-08, 1.36220e-07, 9.32900e-08,
#         3.45570e-07, 1.32640e-07, 3.48560e-07, 3.42810e-07, 1.32570e-07,
#         3.48550e-07, 9.70100e-08, 9.75000e-08, 1.37170e-07, 1.36850e-07,
#         3.57530e-07, 9.40300e-08, 9.59400e-08, 9.61100e-08, 9.63200e-08,
#         9.65700e-08, 1.30610e-07, 3.43640e-07, 9.77600e-08, 9.35200e-08,
#         9.81700e-08, 1.37890e-07, 9.68500e-08, 3.61100e-07, 9.25000e-08,
#         9.50900e-08, 9.47400e-08, 9.47600e-08, 1.37900e-07, 9.33900e-08,
#         9.68000e-08, 1.38040e-07, 9.26900e-08, 1.30140e-07, 1.32940e-07,
#         1.38440e-07, 9.68900e-08, 9.31900e-08, 3.40660e-07, 1.32120e-07,
#         9.28400e-08, 9.74800e-08, 3.49770e-07, 1.37460e-07, 3.51490e-07,
#         9.83400e-08, 1.30800e-07, 3.40920e-07, 1.35790e-07, 3.53960e-07,
#         9.74200e-08, 9.70000e-08, 1.29810e-07, 9.84000e-08, 3.51460e-07,
#         9.73000e-08, 9.79000e-08, 1.38460e-07, 9.79000e-08, 1.29990e-07,
#         9.69400e-08, 3.57110e-07, 1.33960e-07, 9.56300e-08, 9.42700e-08,
#         3.52760e-07, 9.39400e-08, 9.39200e-08, 9.39000e-08, 9.38600e-08,
#         9.74500e-08, 9.28400e-08, 9.36700e-08, 9.45900e-08, 1.35630e-07,
#         9.36600e-08, 9.69200e-08, 3.56610e-07, 9.32600e-08, 3.43830e-07,
#         1.33440e-07, 9.20200e-08, 1.32620e-07, 1.34290e-07, 9.21200e-08,
#         9.44500e-08, 9.80800e-08, 9.72300e-08, 3.53220e-07, 9.68600e-08,
#         9.21500e-08, 1.36840e-07, 9.77300e-08, 1.36900e-07, 3.63110e-07,
#         1.37550e-07, 9.37700e-08, 3.47340e-07, 3.40900e-07, 9.36400e-08]),
#  array([9.37730e-07, 9.46630e-07, 8.85770e-07, 1.04663e-06, 7.99410e-07,
#         8.19920e-07, 1.26172e-06, 6.96770e-07, 5.24610e-07, 5.87680e-07,
#         3.75320e-07, 5.88887e-06, 5.90693e-06, 5.88600e-06, 5.88089e-06,
#         5.87474e-06, 5.87597e-06, 5.88017e-06, 5.87609e-06, 5.88906e-06,
#         5.87994e-06, 5.87331e-06, 5.88077e-06, 5.87704e-06, 2.74810e-07,
#         5.87954e-06, 5.88287e-06, 3.25930e-07, 3.46890e-07, 5.87428e-06,
#         5.87597e-06, 5.89374e-06, 1.12333e-06, 7.14010e-07, 2.67720e-07,
#         5.88200e-07, 3.23730e-07, 3.52980e-07, 5.32490e-07, 3.58630e-07,
#         5.86890e-07, 4.55330e-07, 4.32290e-07, 5.04530e-07, 4.20520e-07,
#         5.14920e-07, 3.61150e-07, 4.13140e-07, 4.51290e-07, 2.97340e-07,
#         3.06720e-07, 4.26370e-07, 3.69740e-07, 3.63650e-07, 3.73330e-07,
#         3.10960e-07, 2.82920e-07, 2.99910e-07, 3.93060e-07, 3.50670e-07,
#         4.75460e-07, 5.99260e-07, 5.11000e-07, 4.98400e-07, 3.44390e-07,
#         2.96980e-07, 3.13400e-07, 3.92100e-07, 3.79890e-07, 5.86270e-07,
#         3.45690e-07, 3.58930e-07, 4.15160e-07, 3.59610e-07, 2.98710e-07,
#         5.00200e-07, 4.49450e-07, 4.50910e-07, 3.44660e-07, 3.44820e-07,
#         5.04760e-07, 5.07970e-07, 3.43150e-07, 3.48280e-07, 3.85150e-07,
#         4.27030e-07, 3.43080e-07, 3.83440e-07, 3.12680e-07, 3.48700e-07,
#         3.76040e-07, 3.08230e-07, 3.48280e-07, 3.81790e-07, 3.52290e-07,
#         2.98280e-07, 4.97650e-07, 3.78840e-07, 3.07200e-07, 3.66550e-07,
#         3.08190e-07, 3.41360e-07, 5.09370e-07, 3.84660e-07, 4.74590e-07,
#         3.84080e-07, 5.06820e-07, 4.47180e-07, 3.53280e-07, 5.81580e-07,
#         3.68980e-07, 3.63110e-07, 3.15400e-07, 3.01320e-07, 3.02910e-07,
#         3.42970e-07, 3.68020e-07, 3.11060e-07, 4.98500e-07, 4.68610e-07,
#         5.09450e-07, 5.12690e-07, 5.94410e-07, 5.01520e-07, 4.18380e-07,
#         3.57270e-07, 3.92280e-07, 2.95750e-07, 2.96980e-07, 3.58230e-07,
#         5.88560e-07, 2.93880e-07, 3.79230e-07, 4.18410e-07, 3.86140e-07,
#         4.22800e-07, 5.79110e-07, 3.43980e-07, 3.52870e-07, 3.45200e-07,
#         4.16000e-07, 3.55240e-07, 3.94250e-07, 3.58240e-07, 2.87580e-07,
#         5.08350e-07, 3.42100e-07, 4.25820e-07, 4.21530e-07, 4.12720e-07,
#         5.01170e-07, 3.62330e-07, 3.53930e-07, 3.02060e-07, 3.75680e-07,
#         4.16000e-07, 4.47930e-07, 3.14500e-07, 3.15950e-07, 2.96220e-07,
#         2.91840e-07, 3.85430e-07, 4.24150e-07, 2.90640e-07, 3.81080e-07,
#         2.85630e-07, 4.16100e-07, 3.44170e-07, 2.97770e-07, 3.88250e-07,
#         2.95800e-07, 3.10040e-07, 4.20210e-07, 5.87170e-07, 4.67600e-07,
#         3.60690e-07, 3.88080e-07, 3.70570e-07, 4.98280e-07, 3.66130e-07,
#         4.26550e-07, 3.57420e-07, 2.86370e-07, 3.15390e-07, 4.19970e-07,
#         3.46690e-07, 3.09880e-07, 3.87670e-07, 3.41330e-07, 4.67170e-07,
#         5.01640e-07, 5.83650e-07, 3.66940e-07, 3.77320e-07, 3.68730e-07,
#         3.67290e-07, 4.24750e-07, 3.64650e-07]),
#  array([1.0603e-07, 1.2759e-07, 1.3092e-07, 1.2612e-07, 1.0463e-07,
#         7.0330e-08, 2.7678e-07, 2.9770e-07, 7.6408e-07, 1.7564e-07,
#         1.6060e-07, 1.3237e-07, 2.1494e-07, 1.7874e-07, 1.2742e-07,
#         1.2591e-07, 8.3530e-08, 2.8120e-07, 2.0818e-07, 1.3961e-07,
#         2.2783e-07, 1.6598e-07, 9.5160e-08, 2.0514e-07, 1.0523e-07,
#         1.1644e-07, 8.3440e-08, 1.1406e-07, 1.4986e-07, 1.1115e-07,
#         7.5850e-08, 1.0500e-07, 1.2854e-07, 1.1508e-07, 7.5050e-08,
#         2.3997e-07, 5.2630e-08, 3.5911e-07, 1.2793e-07, 9.4690e-08,
#         7.8290e-08, 1.2874e-07, 2.1189e-07, 9.9190e-08, 1.3801e-07,
#         6.7170e-08, 1.8078e-07, 6.3780e-08, 1.4300e-07, 5.5350e-08,
#         7.6100e-08, 1.3095e-07, 7.5790e-08, 1.1908e-07, 1.1524e-07,
#         1.3884e-07, 8.8940e-08, 1.3925e-07, 9.6800e-08, 9.9930e-08,
#         8.0290e-08, 8.7600e-08, 1.1150e-07, 1.2100e-07, 7.9280e-08,
#         1.1591e-07, 1.2116e-07, 1.2330e-07, 9.7670e-08, 1.1472e-07,
#         1.2411e-07, 1.1375e-07, 1.3919e-07, 1.2395e-07, 1.1693e-07,
#         8.1450e-08, 1.0089e-07, 1.1494e-07, 1.2283e-07, 1.1470e-07,
#         1.2262e-07, 8.8390e-08, 9.0440e-08, 1.2255e-07, 1.2212e-07,
#         1.1522e-07, 8.1040e-08, 9.0970e-08, 1.3757e-07, 7.9310e-08,
#         1.1607e-07, 9.9750e-08, 1.3552e-07, 8.1550e-08, 9.6990e-08,
#         1.3881e-07, 1.1451e-07, 9.9950e-08, 1.2270e-07, 1.2192e-07,
#         1.2109e-07, 1.2434e-07, 1.1463e-07, 8.1210e-08, 1.3674e-07,
#         8.6600e-08, 1.1264e-07, 7.9660e-08, 1.1180e-07, 1.1686e-07,
#         9.7000e-08, 1.3556e-07, 7.9620e-08, 8.8320e-08, 1.2271e-07,
#         7.9680e-08, 1.3652e-07, 1.1644e-07, 8.1190e-08, 8.0810e-08,
#         1.2372e-07, 9.0700e-08, 1.1627e-07, 1.1735e-07, 1.0193e-07,
#         1.2130e-07, 1.3667e-07, 1.0007e-07, 1.3857e-07, 1.0132e-07,
#         1.1492e-07, 9.0980e-08, 8.0890e-08, 8.0560e-08, 1.2337e-07,
#         1.1591e-07, 1.3865e-07, 8.6570e-08, 8.0450e-08, 1.3676e-07,
#         9.6740e-08, 9.9880e-08, 1.2270e-07, 1.1726e-07, 8.8810e-08,
#         1.1482e-07, 1.1671e-07, 7.9480e-08, 1.1552e-07, 8.6830e-08,
#         9.9100e-08, 1.2128e-07, 8.9080e-08, 8.6790e-08, 9.0800e-08,
#         8.8310e-08, 1.2326e-07, 8.0930e-08]),
#  array([4.4142e-07, 3.0851e-07, 3.0711e-07, 7.9650e-08, 2.0573e-07,
#         1.2401e-07, 1.7201e-07, 3.3578e-07, 3.9263e-07, 2.6106e-07,
#         1.1511e-07, 2.7939e-07, 2.7870e-07, 1.2050e-07, 3.6498e-07,
#         2.2422e-07, 8.2777e-07, 2.7938e-07, 1.7419e-07, 4.7837e-07,
#         6.7090e-07, 1.2454e-07, 2.8442e-07, 8.5691e-07, 1.3405e-07,
#         5.7568e-07, 5.9658e-07, 5.0122e-07, 1.2908e-07, 5.0954e-07,
#         5.3812e-07, 3.7380e-07, 2.5907e-07, 2.5944e-07, 4.3342e-07,
#         6.9736e-07, 5.3011e-07, 1.2421e-07, 2.8730e-07, 1.3180e-07,
#         2.3282e-07, 1.3019e-07, 1.7856e-07, 3.6804e-07, 2.1332e-07,
#         2.4094e-07, 3.2581e-07, 3.9060e-07, 8.5228e-07, 1.9608e-07,
#         1.7629e-07, 1.5579e-07, 1.4083e-07, 3.5678e-07, 4.4857e-07,
#         2.3852e-07, 1.6553e-07, 3.0195e-07, 9.7080e-08, 5.5750e-07,
#         2.9176e-07, 5.2499e-07, 9.2390e-08, 3.2313e-07, 1.9817e-07,
#         2.4090e-07, 2.1431e-07, 2.2490e-07, 1.7716e-07, 1.4652e-07,
#         2.4973e-07, 3.8220e-07, 1.4361e-07, 4.3435e-07, 2.4188e-07,
#         3.7647e-07, 5.6504e-07, 5.1555e-07, 1.5903e-07, 2.4770e-07,
#         1.9978e-07, 3.4344e-07, 2.1295e-07, 1.0920e-07, 4.6600e-07,
#         1.6507e-07, 1.6823e-07, 3.8119e-07, 1.1829e-07, 1.4682e-07,
#         5.0828e-07, 6.0855e-07, 2.5787e-07, 1.9499e-07, 4.9152e-07,
#         2.8198e-07, 1.4452e-07, 1.7306e-07, 2.4031e-07, 2.3746e-07,
#         3.4256e-07, 3.0009e-07, 2.6214e-07, 2.1760e-07, 3.6676e-07,
#         2.0879e-07, 1.3987e-07, 1.8286e-07, 8.1780e-08, 1.9745e-07,
#         1.3917e-07, 1.9936e-07, 7.0560e-08, 2.5098e-07, 1.8871e-07,
#         1.3131e-07, 9.1450e-08, 3.3298e-07, 3.1184e-07, 2.9614e-07,
#         2.7366e-07, 1.9201e-07, 3.4128e-07, 6.3110e-08, 1.5166e-07,
#         4.0721e-07, 2.6356e-07, 1.4178e-07, 1.5437e-07, 9.8040e-08,
#         1.8298e-07, 2.7298e-07, 2.1128e-07, 2.5168e-07, 1.3791e-07,
#         1.9966e-07, 6.2528e-07, 2.6209e-07, 2.0906e-07, 3.8997e-07,
#         2.2435e-07, 1.8332e-07, 2.6905e-07, 1.4730e-07, 2.8694e-07,
#         1.6612e-07, 1.9471e-07, 1.4230e-07, 7.5320e-08, 1.5252e-07,
#         2.1539e-07, 5.4150e-08, 2.4951e-07, 1.2346e-07, 1.4057e-07,
#         3.2188e-07, 1.4531e-07, 1.6794e-07, 1.1296e-07, 1.7412e-07,
#         2.1669e-07, 1.1511e-07, 1.2784e-07, 1.3035e-07, 2.2919e-07,
#         6.3000e-08, 5.8722e-07, 3.8412e-07, 2.6329e-07, 2.5353e-07,
#         1.6061e-07, 2.6862e-07, 3.1165e-07, 6.7405e-07, 2.7286e-07,
#         2.5480e-07, 6.5747e-07, 3.4304e-07, 1.8296e-07, 1.2863e-07,
#         2.8717e-07, 1.8517e-07, 1.6044e-07, 9.4500e-08, 2.0226e-07,
#         1.9035e-07, 2.4180e-07, 4.2962e-07, 1.5715e-07, 2.4578e-07,
#         1.2602e-07, 5.7850e-08, 2.0334e-07, 2.5632e-07, 3.0779e-07,
#         1.6223e-07, 1.9857e-07, 2.6479e-07, 1.0597e-07, 1.7301e-07,
#         2.2823e-07, 2.9399e-07, 2.7620e-07, 6.1400e-08, 2.2418e-07,
#         1.4756e-07, 1.3592e-07, 2.3462e-07, 3.4904e-07, 2.9674e-07,
#         1.1187e-07, 1.5119e-07, 1.7978e-07, 1.5887e-07, 2.7235e-07,
#         2.0427e-07, 3.5304e-07, 1.2681e-07, 1.3783e-07, 1.9512e-07,
#         1.4106e-07, 3.0820e-07, 1.9137e-07, 2.0696e-07, 1.5659e-07,
#         1.2873e-07, 3.5206e-07, 1.2467e-07, 1.1707e-07, 2.0520e-07,
#         1.3200e-07, 1.9008e-07, 2.0971e-07, 1.4283e-07, 3.5681e-07,
#         2.2777e-07, 2.3543e-07, 1.5675e-07, 2.5641e-07, 4.2350e-07,
#         2.6956e-07, 1.9723e-07, 5.4225e-07, 1.3305e-07, 1.7235e-07,
#         1.7539e-07, 2.1334e-07, 2.7016e-07, 2.6259e-07, 1.3667e-07,
#         3.7101e-07, 1.0573e-07, 2.7270e-07, 2.8143e-07, 2.0462e-07,
#         1.2220e-07, 2.8361e-07, 2.6456e-07, 3.1255e-07, 5.2710e-07,
#         1.9932e-07, 1.1779e-07, 1.9222e-07, 6.7384e-07, 3.1951e-07,
#         6.6548e-07, 6.6331e-07, 6.6430e-07, 1.1065e-07, 1.1812e-07,
#         4.0815e-07, 1.4507e-07, 1.2114e-07, 2.6908e-07, 2.6316e-07,
#         2.7699e-07, 1.3881e-07, 3.7545e-07, 2.1914e-07, 2.4014e-07,
#         1.4941e-07, 7.7640e-08, 3.3696e-07, 1.9599e-07, 1.7978e-07,
#         1.6948e-07, 7.3220e-08, 1.6239e-07, 2.8694e-07, 1.5343e-07,
#         3.1014e-07, 1.9355e-07, 1.7905e-07, 1.3327e-07, 3.6750e-07,
#         1.5450e-07, 1.3417e-07, 1.4101e-07, 2.8917e-07, 6.2406e-07,
#         2.4842e-07, 1.0824e-07, 1.9765e-07, 4.0246e-07, 3.0571e-07,
#         2.0654e-07, 1.8268e-07, 2.7008e-07, 6.1960e-07, 2.0735e-07,
#         2.8237e-07, 3.6802e-07, 1.3247e-07, 1.1268e-07, 2.8571e-07,
#         1.1901e-07, 2.5037e-07, 2.5543e-07, 5.6231e-07, 6.7203e-07,
#         9.3340e-08, 1.9955e-07, 1.4720e-07, 1.6092e-07, 2.3397e-07,
#         6.4098e-07, 2.6609e-07, 1.3381e-07, 2.5609e-07, 2.7260e-07,
#         6.5178e-07, 1.0711e-07, 6.1836e-07, 6.3122e-07, 2.3767e-07,
#         1.2101e-07, 2.6006e-07, 2.5233e-07, 2.8654e-07, 5.6598e-07,
#         2.0337e-07, 1.6027e-07, 2.1462e-07, 6.2409e-07, 2.8789e-07,
#         1.0848e-07, 2.7351e-07, 1.5871e-07, 2.0289e-07, 4.2300e-07,
#         4.0488e-07, 3.1112e-07, 1.5023e-07, 1.0535e-07, 1.6933e-07,
#         2.1839e-07, 2.5162e-07, 1.5668e-07, 2.0337e-07, 1.8738e-07,
#         1.8568e-07, 1.0185e-07, 2.5587e-07, 1.2891e-07, 4.0426e-07,
#         2.3798e-07, 3.4345e-07, 2.5896e-07, 1.4049e-07, 2.1888e-07,
#         1.4552e-07, 1.9369e-07, 1.3774e-07, 2.0923e-07, 1.9660e-07,
#         1.5245e-07, 1.5503e-07, 2.5533e-07, 1.7883e-07, 2.6142e-07,
#         3.8275e-07, 1.7454e-07, 1.1430e-07, 1.0810e-07, 7.2750e-08,
#         1.4020e-07, 2.2600e-07, 1.2202e-07, 1.5800e-07, 9.9310e-08,
#         1.0825e-07, 2.7139e-07, 3.2324e-07, 7.5760e-08, 6.2589e-07,
#         1.5187e-07, 2.5385e-07, 1.6190e-07, 2.7042e-07, 1.1425e-07,
#         1.2630e-07, 2.1715e-07, 2.6098e-07, 1.2770e-07, 2.3051e-07,
#         2.4795e-07, 2.5444e-07, 3.6999e-07, 3.8271e-07, 1.6637e-07,
#         1.6094e-07, 2.1731e-07, 2.0510e-07, 2.9595e-07, 1.7560e-07,
#         1.3436e-07, 2.1619e-07, 1.4440e-07, 1.7099e-07, 1.9979e-07,
#         2.0791e-07, 1.5319e-07, 1.9623e-07, 1.7420e-07, 2.7305e-07,
#         4.0206e-07, 3.6899e-07, 1.2175e-07, 2.7810e-07, 2.0669e-07,
#         6.5790e-08, 1.3077e-07, 1.4726e-07, 1.8985e-07, 6.0168e-07,
#         2.1032e-07, 6.1069e-07, 2.5415e-07, 1.8486e-07, 1.1332e-07,
#         1.7158e-07, 1.9741e-07, 1.8571e-07, 2.6579e-07, 9.7950e-08,
#         1.0697e-07, 1.9376e-07, 3.6691e-07, 1.2637e-07, 1.9963e-07,
#         9.8950e-08, 2.5008e-07, 3.9030e-07, 2.4809e-07, 3.3832e-07,
#         7.7000e-08, 3.6930e-07, 3.8951e-07, 2.1424e-07, 6.0763e-07,
#         1.3593e-07, 1.6140e-07, 1.2134e-07, 1.3044e-07, 2.7716e-07,
#         1.5287e-07, 1.7053e-07, 1.2700e-07, 1.5753e-07, 2.4671e-07,
#         1.6892e-07, 1.4140e-07, 1.2223e-07, 2.7924e-07, 9.7760e-08,
#         1.6291e-07, 2.5533e-07, 2.6531e-07, 1.6576e-07, 2.8028e-07,
#         1.3235e-07, 2.6842e-07, 1.5988e-07, 2.7259e-07, 1.0570e-07,
#         2.7153e-07, 3.3300e-07, 2.8773e-07, 2.0062e-07, 2.2481e-07,
#         6.5676e-07, 4.5632e-07, 1.9520e-07, 2.5442e-07, 1.1514e-07,
#         1.7712e-07, 1.6823e-07, 1.4757e-07, 1.1732e-07, 4.0672e-07,
#         4.1715e-07, 2.5640e-07, 2.5562e-07, 1.3994e-07, 2.4979e-07,
#         2.7597e-07, 2.6598e-07, 2.7801e-07, 1.3359e-07, 2.5790e-07,
#         2.9392e-07, 6.1060e-08, 2.7352e-07, 1.2700e-07, 2.5593e-07,
#         1.6151e-07, 2.6959e-07, 5.4223e-07, 4.5409e-07, 1.4703e-07,
#         1.7878e-07, 1.8786e-07, 1.4629e-07, 3.1779e-07, 1.5781e-07,
#         1.7316e-07, 1.0927e-07, 2.6609e-07, 6.2699e-07, 5.3829e-07,
#         1.1280e-07, 6.6030e-08, 2.4706e-07, 1.2462e-07, 1.0785e-07,
#         2.5356e-07, 1.2691e-07, 4.0934e-07, 1.4350e-07, 2.7864e-07,
#         7.1640e-08, 2.7019e-07, 1.6472e-07, 1.6522e-07, 1.1968e-07,
#         1.5883e-07, 4.2080e-07, 2.3986e-07, 1.3226e-07, 3.2781e-07,
#         2.7564e-07, 3.1191e-07, 1.0389e-07, 3.3860e-07, 3.4302e-07,
#         1.3104e-07, 6.1044e-07, 1.5431e-07, 1.1977e-07, 1.3969e-07,
#         1.4482e-07, 1.1495e-07, 2.7776e-07, 2.6435e-07, 2.7080e-07,
#         2.5878e-07, 4.0146e-07, 1.2081e-07, 1.4901e-07, 2.2105e-07,
#         2.6071e-07, 2.1162e-07, 2.2526e-07]),
#  array([5.63140e-07, 5.87040e-07, 8.06870e-07, 6.34280e-07, 6.09430e-07,
#         3.47160e-07, 5.06270e-07, 7.15770e-07, 5.62730e-07, 1.00100e-06,
#         7.26850e-07, 1.14705e-06, 6.31100e-07, 5.16270e-07, 4.90900e-07,
#         6.97040e-07, 5.46580e-07, 1.00651e-06, 6.48400e-07, 3.88470e-07,
#         3.87360e-07, 2.68140e-07, 4.64260e-07, 4.96360e-07, 7.31530e-07,
#         1.33368e-06, 8.42580e-07, 7.88760e-07, 9.78250e-07, 6.40170e-07,
#         1.03973e-06, 8.19660e-07, 7.65890e-07, 1.03870e-06, 1.38387e-06,
#         6.32040e-07, 8.13780e-07, 7.10440e-07, 6.20750e-07, 5.62010e-07,
#         8.44110e-07, 4.91340e-07, 6.85210e-07, 5.28790e-07, 8.15160e-07,
#         6.50260e-07, 8.16710e-07, 6.82680e-07, 2.94190e-07, 7.35630e-07,
#         7.65650e-07, 7.80520e-07, 6.09220e-07, 7.73110e-07, 7.29670e-07,
#         8.40890e-07, 9.89060e-07, 9.63690e-07, 9.46230e-07, 8.08340e-07,
#         8.65520e-07, 7.38520e-07, 8.33160e-07, 5.17020e-07, 9.04660e-07,
#         8.18220e-07, 8.80550e-07, 8.95800e-07, 8.30410e-07, 5.67160e-07,
#         4.51570e-07, 5.67740e-07, 8.89020e-07, 8.83830e-07, 5.54200e-07,
#         5.42020e-07, 8.82660e-07, 7.28970e-07, 8.54880e-07, 7.81640e-07,
#         8.41120e-07, 6.72630e-07, 7.84610e-07, 8.19040e-07, 9.90740e-07,
#         1.07109e-06, 9.24930e-07, 6.23780e-07, 7.95010e-07, 7.95710e-07,
#         1.06558e-06, 1.02679e-06, 5.81300e-07, 6.74740e-07, 8.38440e-07,
#         6.52740e-07, 8.82860e-07, 8.87270e-07, 1.09384e-06, 9.99400e-07,
#         9.84100e-07, 1.10053e-06, 7.64540e-07, 1.19675e-06, 8.25550e-07,
#         8.20770e-07, 6.73570e-07, 6.19160e-07, 4.78980e-07, 4.36780e-07,
#         5.66790e-07, 1.14019e-06, 6.64340e-07, 5.26250e-07, 5.62480e-07,
#         7.68930e-07, 9.95660e-07, 6.35030e-07, 1.17172e-06, 7.63580e-07,
#         6.00680e-07, 9.90370e-07, 4.70070e-07, 9.91660e-07, 6.63050e-07,
#         1.18647e-06, 5.29000e-07, 4.54080e-07, 6.71060e-07, 6.68670e-07,
#         6.65010e-07, 1.15439e-06, 8.08660e-07, 1.17314e-06, 6.47100e-07,
#         1.16175e-06, 4.61540e-07, 6.42020e-07, 7.91190e-07, 6.44100e-07,
#         1.00502e-06, 6.68310e-07, 4.52050e-07, 9.83200e-07, 1.13704e-06,
#         8.28780e-07, 4.38370e-07, 6.58540e-07, 7.85060e-07, 9.87380e-07,
#         7.87630e-07, 1.16373e-06, 4.61950e-07, 8.16660e-07, 1.01316e-06,
#         1.00250e-06, 1.00830e-06, 6.71690e-07, 6.52770e-07, 6.66390e-07,
#         6.33430e-07, 4.55550e-07, 6.24970e-07, 5.80200e-07, 1.00549e-06,
#         1.18214e-06, 1.01852e-06, 1.11016e-06, 6.00130e-07, 4.73510e-07,
#         7.73390e-07, 1.01197e-06, 4.60070e-07, 5.32860e-07, 1.01613e-06,
#         8.09960e-07, 1.12658e-06, 6.54880e-07, 1.09378e-06, 1.01818e-06,
#         5.64200e-07, 5.83220e-07, 5.83640e-07, 9.89000e-07, 5.79110e-07,
#         8.31180e-07, 5.71320e-07, 6.16370e-07, 1.10000e-06, 8.02630e-07,
#         5.80090e-07, 5.71140e-07, 6.54840e-07, 6.51920e-07, 5.88740e-07,
#         7.91560e-07, 4.75150e-07, 1.12742e-06, 6.37780e-07, 4.56580e-07,
#         6.01200e-07, 7.73270e-07, 1.13101e-06, 8.04530e-07, 6.07550e-07,
#         9.85900e-07, 6.37710e-07, 4.55010e-07, 4.69490e-07, 5.66170e-07,
#         6.63690e-07, 6.79260e-07, 7.77450e-07, 1.14813e-06, 7.80510e-07,
#         8.27870e-07, 9.93160e-07, 5.28160e-07, 1.00332e-06, 8.30610e-07,
#         4.40320e-07, 9.79200e-07, 6.83030e-07, 4.77410e-07, 7.68030e-07,
#         6.25250e-07, 1.01135e-06, 5.88420e-07, 8.26900e-07, 1.08433e-06,
#         1.16611e-06, 1.14630e-06, 1.18726e-06, 1.11673e-06, 6.55480e-07,
#         1.09796e-06, 9.82910e-07, 5.62010e-07, 1.00020e-06, 5.23570e-07,
#         7.90970e-07, 6.20880e-07, 6.87000e-07, 6.28360e-07, 1.02397e-06,
#         1.00137e-06, 8.06050e-07, 9.94270e-07, 5.82600e-07, 1.00858e-06,
#         6.69590e-07, 1.02199e-06]),
#  array([4.90970e-07, 8.07100e-08, 4.88750e-07, 1.31580e-07, 5.91950e-07,
#         7.66850e-07, 1.08807e-06, 5.77810e-07, 3.85520e-07, 1.81170e-07,
#         2.04190e-07, 2.26800e-07, 2.79890e-07, 2.06460e-07, 4.86920e-07,
#         2.98580e-07, 9.61900e-08, 2.17760e-07, 1.94600e-07, 1.76270e-07,
#         2.53800e-07, 1.68420e-07, 1.06032e-06, 1.81080e-07, 1.06242e-06,
#         2.26390e-07, 1.41230e-07, 6.24470e-07, 1.27900e-07, 1.50630e-07,
#         3.02410e-07, 1.96820e-07, 5.16580e-07, 1.93280e-07, 1.53445e-06,
#         2.26130e-07, 1.98240e-07, 7.77170e-07, 1.93700e-07, 1.47600e-07,
#         4.49530e-07, 5.54980e-07, 2.54940e-07, 1.56520e-07, 4.41920e-07,
#         1.72160e-07, 7.04910e-07, 1.82170e-07, 3.23210e-07, 2.31680e-07,
#         3.68280e-07, 7.74150e-07, 1.76540e-07, 1.11389e-06, 1.36286e-06,
#         2.01450e-07, 8.21770e-07, 2.17600e-07, 2.28750e-07, 9.69950e-07,
#         7.27690e-07, 2.24760e-07, 6.80610e-07, 2.52750e-07, 2.65810e-07,
#         9.43890e-07, 1.76160e-07, 1.16167e-06, 1.89610e-07, 4.72670e-07,
#         9.14150e-07, 2.83920e-07, 6.58060e-07, 2.00640e-07, 3.14680e-07,
#         4.97760e-07, 2.85020e-07, 6.22380e-07, 2.64350e-07, 1.02850e-07,
#         2.71480e-07, 2.06430e-07, 2.50400e-07, 1.91070e-07, 3.56210e-07,
#         6.37270e-07, 8.14500e-07, 3.63620e-07, 3.36050e-07, 1.89420e-07,
#         2.10570e-07, 4.21840e-07, 1.96780e-07, 1.87960e-07, 2.15340e-07,
#         2.18960e-07, 1.97030e-07, 3.61180e-07, 2.01210e-07, 4.37480e-07,
#         2.00710e-07, 2.81880e-07, 4.96270e-07, 3.37590e-07, 3.48680e-07,
#         3.61390e-07, 2.03130e-07, 2.84190e-07, 1.93040e-07, 2.66150e-07,
#         1.93280e-07, 1.87850e-07, 1.93980e-07, 1.93100e-07, 1.92480e-07,
#         1.90050e-07, 2.41500e-07, 2.33750e-07, 3.18670e-07, 2.07320e-07,
#         2.00380e-07, 1.97320e-07, 3.16290e-07, 2.49010e-07, 2.71030e-07,
#         2.11850e-07, 3.64370e-07, 2.00750e-07, 1.96890e-07, 1.95330e-07,
#         2.02450e-07, 1.99350e-07, 2.55310e-07, 2.44440e-07, 1.92950e-07,
#         2.02540e-07, 2.05020e-07, 1.88190e-07, 1.87710e-07, 2.71420e-07,
#         2.60340e-07, 1.91290e-07, 1.81710e-07, 1.81720e-07, 1.78880e-07,
#         2.63890e-07, 2.78630e-07, 1.66760e-07, 1.72300e-07, 1.72650e-07,
#         2.32730e-07, 2.18690e-07, 2.41670e-07, 1.86390e-07, 1.81940e-07,
#         2.21200e-07, 1.76920e-07, 2.48350e-07, 1.74320e-07, 2.20310e-07,
#         1.82540e-07, 2.22680e-07, 1.77540e-07, 1.80980e-07, 2.25510e-07,
#         2.96870e-07, 1.83810e-07, 2.08490e-07, 1.81670e-07, 1.79580e-07,
#         2.23060e-07, 3.35300e-07, 1.77830e-07, 1.79310e-07, 1.84540e-07,
#         1.89270e-07, 2.25560e-07, 1.86220e-07, 3.13000e-07, 1.96580e-07,
#         2.53370e-07, 1.87270e-07, 1.78230e-07, 1.92280e-07, 1.81790e-07,
#         1.85730e-07, 2.97070e-07, 2.40230e-07, 1.96730e-07, 1.88490e-07,
#         2.76140e-07, 2.43980e-07, 2.46080e-07, 2.57900e-07, 1.86400e-07,
#         1.88280e-07, 2.60910e-07, 2.21210e-07, 2.15120e-07, 2.06290e-07,
#         2.17340e-07, 2.30340e-07, 3.06830e-07, 3.48340e-07, 1.99390e-07,
#         2.13670e-07, 1.76330e-07, 1.80940e-07, 2.26650e-07, 1.80410e-07,
#         2.96670e-07, 1.99760e-07, 2.63950e-07, 1.92300e-07, 1.92350e-07,
#         3.12440e-07, 1.95130e-07, 3.53110e-07, 2.62060e-07, 1.98210e-07,
#         1.97290e-07, 1.90660e-07, 1.83530e-07, 1.79300e-07, 1.79590e-07,
#         2.38130e-07, 3.02280e-07, 1.83750e-07, 1.80680e-07, 2.74140e-07,
#         3.01620e-07, 2.22300e-07, 1.86050e-07, 3.13060e-07, 1.97210e-07,
#         1.84550e-07, 1.84820e-07, 2.25890e-07, 2.42880e-07, 2.21070e-07,
#         2.98120e-07, 1.90210e-07, 1.87910e-07, 2.22670e-07, 1.95130e-07,
#         1.95210e-07, 1.93160e-07, 1.96820e-07, 1.98020e-07, 1.96000e-07,
#         1.93560e-07, 1.90930e-07, 2.73250e-07, 3.06350e-07, 2.23180e-07,
#         3.01720e-07, 1.83480e-07, 1.84290e-07, 2.69460e-07, 1.85100e-07,
#         2.68060e-07, 1.83620e-07, 1.95500e-07, 1.87900e-07, 1.97990e-07,
#         1.96740e-07, 1.98020e-07, 1.80510e-07, 1.82390e-07, 2.66890e-07,
#         1.83450e-07, 3.14050e-07, 1.95900e-07, 2.63200e-07, 2.68990e-07,
#         2.63760e-07, 1.83610e-07, 1.80240e-07, 3.42420e-07, 1.98450e-07,
#         3.05990e-07, 2.99140e-07, 3.45510e-07, 1.82520e-07, 1.91930e-07,
#         1.80260e-07, 1.86100e-07, 3.14320e-07, 1.87400e-07, 1.81410e-07,
#         3.41650e-07, 1.96680e-07, 2.40280e-07, 2.65140e-07, 1.84330e-07,
#         1.92340e-07, 2.60450e-07, 2.36960e-07, 1.98070e-07, 2.40550e-07,
#         2.21240e-07, 2.66210e-07, 1.85330e-07, 1.84840e-07, 1.95070e-07,
#         1.92900e-07, 3.12110e-07, 2.37620e-07, 2.36710e-07, 2.40210e-07,
#         1.79700e-07, 1.94320e-07, 3.08310e-07, 1.93800e-07, 2.26820e-07,
#         2.38350e-07, 2.67720e-07, 2.72200e-07, 1.83180e-07, 1.83270e-07,
#         3.45200e-07, 1.79360e-07, 3.00900e-07, 2.40150e-07, 3.45140e-07,
#         1.82640e-07, 3.13980e-07, 2.74450e-07, 1.93380e-07, 3.03420e-07,
#         1.82540e-07, 1.85990e-07, 2.60890e-07, 1.95100e-07, 1.85060e-07,
#         1.83740e-07, 1.83070e-07, 3.12490e-07, 1.92310e-07, 3.04550e-07,
#         2.41460e-07, 2.66210e-07, 1.84870e-07, 1.81110e-07, 1.94040e-07,
#         1.92450e-07, 3.00610e-07, 1.95860e-07, 2.63130e-07, 1.83410e-07,
#         1.88530e-07, 1.87650e-07, 2.19950e-07, 1.80740e-07, 1.97470e-07,
#         2.71420e-07, 3.52350e-07, 1.95810e-07, 3.42530e-07, 1.87160e-07,
#         2.26300e-07, 3.03030e-07, 1.94540e-07, 1.95670e-07, 1.95130e-07,
#         2.60760e-07, 1.80720e-07, 1.81440e-07, 1.79370e-07, 1.91480e-07,
#         1.82010e-07]),
#  array([3.34320e-07, 2.12280e-07, 2.55530e-07, 1.65600e-07, 3.31520e-07,
#         2.02500e-07, 2.08310e-07, 1.77490e-07, 4.95310e-07, 3.15990e-07,
#         2.38550e-07, 3.28010e-07, 4.90080e-07, 1.43980e-07, 1.43220e-07,
#         1.24270e-07, 1.44860e-07, 1.90440e-07, 2.17670e-07, 3.20690e-07,
#         3.22570e-07, 3.34840e-07, 4.72950e-07, 1.73060e-07, 3.79980e-07,
#         1.44890e-07, 2.29810e-07, 1.62730e-07, 3.99740e-07, 2.82910e-07,
#         3.12210e-07, 1.42430e-07, 2.11270e-07, 3.16980e-07, 1.04680e-07,
#         2.05570e-07, 2.49330e-07, 4.16080e-07, 1.25480e-07, 6.69610e-07,
#         8.65160e-07, 6.08900e-07, 2.77440e-07, 1.79500e-07, 2.14020e-07,
#         2.11380e-07, 2.87260e-07, 2.76320e-07, 3.63390e-07, 2.12980e-07,
#         3.35670e-07, 6.12040e-07, 5.05190e-07, 1.13950e-07, 1.71660e-07,
#         3.21220e-07, 5.40730e-07, 1.70592e-06, 8.95500e-08, 1.74610e-07,
#         1.15570e-07, 1.78690e-07, 8.81000e-08, 1.35832e-06, 2.32420e-07,
#         7.33900e-08, 8.38870e-07, 5.72730e-07, 9.87100e-08, 9.80600e-08,
#         1.75290e-07, 8.02150e-07, 3.83400e-07, 3.53990e-07, 1.48104e-06,
#         9.02600e-08, 6.16870e-07, 1.45162e-06, 1.03150e-07, 6.62330e-07,
#         5.57560e-07, 9.75700e-08, 8.79200e-08, 9.53700e-08, 2.22420e-07,
#         5.30130e-07, 9.41900e-08, 5.84750e-07, 1.87360e-07, 1.04090e-07,
#         1.80330e-07, 1.05520e-07, 9.95700e-08, 9.02200e-08, 1.92200e-07,
#         5.33940e-07, 3.36320e-07, 1.73490e-07, 3.03750e-07, 3.03740e-07,
#         5.61540e-07, 5.08620e-07, 8.01800e-08, 2.30230e-07, 9.24400e-08,
#         1.82310e-07, 8.12120e-07, 1.83980e-07, 1.77250e-07, 9.48000e-08,
#         1.65260e-07, 3.41210e-07, 5.61170e-07, 9.00020e-07, 1.80940e-07,
#         9.64300e-08, 1.54525e-06, 1.71730e-07, 3.08520e-07, 1.65822e-06,
#         8.07700e-08, 1.56005e-06, 3.33350e-07, 1.87670e-07, 5.28250e-07,
#         1.05780e-07, 2.39070e-07, 1.81120e-07, 1.70750e-07, 9.73000e-08,
#         5.60460e-07, 1.92100e-07, 8.57710e-07, 1.53718e-06, 1.62220e-07,
#         1.61310e-07, 7.98610e-07, 5.89690e-07, 9.99600e-08, 1.10910e-07,
#         1.05150e-07, 1.64710e-07, 3.34440e-07, 1.28147e-06, 5.18730e-07,
#         5.43560e-07, 6.25730e-07, 9.18200e-08, 3.30310e-07, 7.95700e-08,
#         9.04300e-08, 5.54330e-07, 8.88900e-08, 1.37642e-06, 2.53290e-07,
#         1.64230e-07, 1.50285e-06, 8.54100e-07, 1.76720e-07, 3.08360e-07,
#         2.15440e-07, 2.49660e-07, 2.37760e-07, 1.88200e-07, 3.24050e-07,
#         1.56407e-06, 3.03030e-07, 7.93620e-07, 5.68890e-07, 1.88420e-07,
#         2.02000e-07, 1.77650e-07, 2.28240e-07, 3.20150e-07, 1.00500e-07,
#         1.86970e-07, 2.09790e-07, 3.23450e-07, 5.56210e-07, 5.50840e-07,
#         1.48019e-06, 1.65050e-07, 8.29800e-08, 1.10310e-07, 1.14210e-07,
#         3.48790e-07, 1.88890e-07, 8.72700e-08, 3.47750e-07, 3.43310e-07,
#         1.71480e-07, 1.00280e-07]),
#  array([5.56790e-07, 9.89130e-07, 1.06030e-07, 5.97850e-07, 3.39790e-07,
#         7.57200e-08, 1.64850e-07, 1.34310e-07, 3.99420e-07, 2.04980e-07,
#         7.35520e-07, 2.92310e-07, 4.60630e-07, 6.21600e-08, 7.07950e-07,
#         1.55389e-06, 7.21870e-07, 1.33150e-07, 2.49650e-07, 1.92020e-07,
#         1.17060e-07, 1.78080e-07, 4.13710e-07, 1.51450e-07, 9.61830e-07,
#         1.76330e-07, 2.71600e-07, 2.14350e-07, 1.15330e-07, 2.85460e-07,
#         7.67230e-07, 8.82200e-08, 3.38230e-07, 1.07340e-07, 1.37470e-07,
#         1.18450e-07, 1.47250e-07, 7.46150e-07, 6.65900e-08, 1.88190e-07,
#         3.57430e-07, 8.23440e-07, 1.70950e-07, 7.99430e-07, 2.81750e-07,
#         2.07040e-07, 2.54040e-07, 1.23520e-07, 1.17120e-07, 1.15660e-07,
#         4.48820e-07, 3.25381e-06, 2.57860e-07, 1.84890e-07, 4.02070e-07,
#         2.60770e-07, 5.82900e-08, 6.07875e-06, 1.94170e-07, 1.80585e-06,
#         3.59380e-07, 3.82770e-07, 2.03338e-06, 6.15540e-07, 1.16080e-07,
#         2.17948e-06, 6.27140e-07, 2.95230e-07, 2.59400e-07, 1.74420e-07,
#         5.72860e-07, 4.54500e-08, 4.69910e-07, 9.22500e-08, 2.42270e-07,
#         4.50030e-07, 1.85922e-06, 4.70150e-07, 9.52900e-08, 1.26261e-06,
#         1.19140e-07, 2.92520e-07, 1.89350e-07, 1.28524e-06, 4.84590e-07,
#         2.36040e-07, 7.14500e-07, 9.10040e-07, 1.28940e-07, 6.11090e-07,
#         3.57160e-07, 3.20890e-07, 3.37490e-07, 1.99470e-07, 3.04400e-07,
#         1.22120e-07, 1.40666e-06, 1.59722e-06, 4.50830e-07, 6.03510e-07,
#         1.01109e-06, 5.49900e-08, 9.70600e-08, 2.74640e-07, 5.39900e-07,
#         1.08500e-07, 1.21130e-07, 4.10200e-07, 5.82760e-07, 8.44000e-08,
#         8.18600e-08, 2.60980e-07, 5.97050e-07, 1.01120e-07, 2.85140e-07,
#         6.02610e-07, 1.36533e-06, 4.28230e-07, 6.69800e-07, 1.05050e-07,
#         3.93820e-07, 5.63700e-08, 3.83170e-07, 4.73080e-07, 4.95900e-07,
#         2.93710e-07, 7.95100e-08, 5.91100e-08, 1.07156e-06, 1.39484e-06,
#         8.27100e-08, 5.11470e-07, 1.19490e-07, 1.18430e-07, 2.53590e-07,
#         2.83270e-07, 1.13010e-07, 8.19700e-08, 2.88560e-07, 1.11930e-07,
#         8.94000e-08, 1.50280e-06, 6.70600e-07, 9.00700e-08, 8.82400e-08,
#         3.90700e-07, 1.45975e-06, 1.01770e-07, 6.21250e-07, 4.09450e-07,
#         1.14880e-07, 5.06720e-07, 1.02435e-06, 5.79270e-07, 1.22340e-07,
#         9.56800e-08, 1.45626e-06, 8.59500e-08, 1.09790e-07, 1.12390e-07,
#         1.16870e-07, 5.07010e-07, 8.01600e-08, 1.26940e-07, 6.25800e-08,
#         1.03310e-07, 7.78300e-08, 1.07460e-07, 1.37380e-06, 1.12009e-06,
#         2.94820e-07, 6.27360e-07, 8.78200e-08, 8.13000e-08, 9.64600e-08,
#         4.02800e-07, 5.84200e-08, 6.11810e-07, 5.49740e-07, 4.23230e-07,
#         1.57895e-06, 2.89430e-07, 4.63540e-07, 8.98900e-08, 9.89470e-07,
#         1.16380e-07, 6.58120e-07, 2.85250e-07, 2.70270e-07, 4.09530e-07,
#         1.20030e-07, 1.17570e-07, 9.14800e-08, 2.85680e-07, 4.16270e-07,
#         1.27190e-07, 5.44290e-07, 5.78920e-07, 1.16470e-07, 1.11466e-06,
#         2.54850e-07, 1.14690e-07, 1.46978e-06, 6.58500e-07, 2.55300e-07,
#         1.46103e-06, 8.79300e-08, 1.25090e-07, 1.20300e-07, 6.58260e-07,
#         1.43865e-06, 4.99810e-07]),
#  array([1.79460e-07, 1.52470e-07, 1.61230e-07, 7.91710e-07, 4.14570e-07,
#         1.28300e-07, 1.15440e-07, 3.03530e-07, 8.47000e-08, 5.50970e-07,
#         3.80360e-07, 1.11010e-07, 5.48660e-07, 1.53430e-07, 8.43470e-07,
#         1.11290e-07, 1.22846e-06, 2.49470e-07, 1.54690e-07, 5.01650e-07,
#         2.75060e-07, 3.08760e-07, 9.38410e-07, 4.63040e-07, 6.88478e-06,
#         3.84250e-07, 4.95390e-07, 8.71900e-08, 5.40000e-07, 2.63990e-07,
#         2.72530e-07, 8.37700e-08, 3.98330e-07, 1.98480e-07, 9.05600e-08,
#         4.52809e-06, 9.80620e-07, 4.77100e-07, 1.68210e-07, 3.05939e-06,
#         1.87340e-07, 4.72590e-07, 2.55770e-07, 3.13720e-07, 3.60060e-07,
#         6.08600e-08, 1.30757e-06, 6.08200e-07, 7.64460e-07, 5.01700e-07,
#         4.18310e-07, 1.98310e-07, 1.79630e-07, 1.54901e-06, 2.20240e-07,
#         2.08947e-06, 3.18960e-07, 1.37280e-07, 1.48130e-07, 1.12650e-07,
#         1.79270e-07, 5.34120e-07, 1.37050e-07, 2.99240e-07, 1.97586e-06,
#         5.35130e-07, 1.33400e-07, 5.67200e-07, 1.64270e-07, 1.30720e-07,
#         1.40920e-07, 7.85350e-07, 1.47649e-06, 1.39485e-06, 2.06718e-06,
#         3.44390e-07, 2.01054e-06, 1.54140e-07, 6.82600e-08, 6.15870e-07,
#         1.99181e-06, 1.16410e-07, 6.73570e-07, 7.86320e-07, 2.41350e-07,
#         1.81127e-06, 1.24980e-07, 4.28870e-07, 1.93820e-07, 1.25370e-07,
#         2.22120e-07, 1.43980e-07, 1.10840e-07, 1.31601e-06, 6.93750e-07,
#         3.96580e-07, 6.80600e-08, 2.02369e-06, 6.83140e-07, 1.25280e-07,
#         1.66560e-07, 1.25628e-06, 1.96700e-07, 1.97000e-07, 3.67240e-07,
#         2.26450e-07, 6.87700e-08, 4.09070e-07, 1.43180e-07, 3.41100e-07,
#         1.14040e-07, 1.28105e-06, 1.87100e-07, 1.37309e-06, 1.12070e-07,
#         1.75713e-06, 1.45300e-07, 3.93820e-07, 1.90600e-07, 1.33490e-07,
#         1.16080e-07, 1.07940e-07, 1.92260e-07, 1.35800e-07, 3.09350e-07,
#         1.70552e-06, 7.70420e-07, 5.72820e-07, 1.84300e-07, 3.16280e-07,
#         3.05900e-07, 7.57710e-07, 3.51850e-07, 6.82450e-07, 1.75978e-06,
#         2.27500e-07, 3.19060e-07, 6.97420e-07, 1.23807e-06, 1.03690e-07,
#         1.23247e-06, 8.32320e-07, 1.33383e-06, 1.50973e-06, 1.76420e-07,
#         5.88190e-07, 2.05938e-06, 4.41750e-07, 1.61322e-06, 1.90940e-07,
#         1.47650e-07, 4.46180e-07, 1.74510e-07, 4.93300e-07, 1.54800e-07,
#         1.93430e-07, 6.25500e-08, 2.19150e-07, 3.97300e-07, 1.11330e-07,
#         1.37240e-07, 6.33800e-08, 1.62590e-06, 1.87190e-07, 6.46200e-08,
#         3.29370e-07, 6.43400e-08, 1.95200e-07, 1.44435e-06, 6.52400e-08,
#         5.01280e-07, 1.50110e-07, 1.08420e-07, 2.18220e-07, 1.09360e-07,
#         2.07530e-06, 1.28300e-07, 3.40140e-07, 1.85290e-07, 1.25567e-06,
#         1.70440e-07]),
#  array([1.03253e-06, 9.85580e-07, 3.52000e-07, 4.16200e-07, 1.69690e-06,
#         1.10399e-06, 3.28673e-06, 1.23059e-06, 5.96540e-07, 4.67500e-07,
#         9.30710e-07, 1.21385e-06, 2.09780e-07, 4.46640e-07, 9.01480e-07,
#         1.16609e-06, 6.22740e-07, 9.47740e-07, 5.62550e-07, 8.98190e-07,
#         1.33614e-06, 4.72200e-07, 1.07553e-06, 8.28920e-07, 1.15591e-06,
#         8.05990e-07, 1.31690e-06, 6.19320e-07, 1.00907e-06, 1.69707e-06,
#         1.74134e-06, 7.49220e-07, 8.27460e-07, 8.42870e-07, 1.06019e-06,
#         2.99310e-07, 3.11840e-07, 6.91270e-07, 8.71390e-07, 3.57850e-07,
#         7.32910e-07, 6.61710e-07, 5.25140e-07, 1.99732e-06, 3.41070e-07,
#         4.84920e-07, 1.29492e-06, 5.68960e-07, 1.53285e-06, 1.01193e-06,
#         1.04653e-06, 2.37103e-06, 1.04684e-06, 3.79970e-07, 7.52610e-07,
#         2.58164e-06, 1.72188e-06, 1.05524e-06, 5.84640e-07, 5.14730e-07,
#         7.84800e-07, 4.90300e-07, 6.88130e-07, 8.25460e-07, 1.15430e-06,
#         9.98750e-07, 1.30258e-06, 1.18273e-06, 9.52780e-07, 4.16651e-06,
#         1.04011e-06, 1.46076e-06, 1.55444e-06, 3.73310e-07, 5.14190e-07,
#         9.49250e-07, 2.79100e-07, 4.00250e-07, 7.00200e-07, 3.19270e-07,
#         5.07640e-07, 6.57560e-07, 5.52260e-07, 3.07380e-07, 6.69050e-07,
#         4.78324e-06, 4.16060e-07, 2.24856e-06, 4.18618e-06, 2.07264e-06,
#         3.77570e-07, 5.10020e-07, 4.24010e-07, 2.05415e-06, 9.56510e-07,
#         3.08660e-07, 1.49720e-06, 1.58242e-06, 6.74970e-07, 4.19670e-07,
#         1.02871e-06, 2.94770e-07, 2.90930e-07, 2.26672e-06, 2.24344e-06,
#         2.35021e-06, 5.25330e-07, 3.13280e-07, 3.79900e-07, 3.96170e-07,
#         5.64170e-07, 1.36709e-06, 2.15884e-06, 9.58140e-07, 3.94760e-07,
#         1.01477e-06, 3.87810e-07, 1.02604e-06, 4.19280e-07, 9.46600e-07,
#         2.14788e-06, 8.76450e-07, 1.06711e-06, 4.26170e-07, 7.33900e-07,
#         3.71320e-07, 1.51524e-06, 3.90270e-07, 7.14310e-07, 9.82360e-07,
#         5.02120e-07, 9.50530e-07, 6.80180e-07, 5.25420e-07, 1.06117e-06,
#         7.32070e-07, 5.04640e-07, 4.04900e-07, 3.21330e-07, 4.50440e-06,
#         2.34369e-06, 3.03120e-07, 6.87040e-07, 5.03110e-07, 1.14177e-06,
#         4.23010e-07, 2.10057e-06, 5.17450e-07, 3.96640e-07, 5.16410e-07,
#         1.02674e-06, 5.30550e-07, 4.98550e-07, 2.08972e-06, 4.93680e-07,
#         3.17850e-07, 4.61466e-06, 2.16069e-06, 9.15770e-07, 3.96500e-07,
#         4.16930e-07, 4.33720e-06, 2.09756e-06, 9.54440e-07, 3.17700e-07,
#         2.94530e-07, 3.82850e-07, 5.09580e-07, 3.70900e-07, 4.38693e-06,
#         6.79230e-07, 9.50970e-07, 4.61111e-06, 6.97780e-07, 2.87850e-07,
#         5.41260e-07, 1.67562e-06, 2.17178e-06, 3.08320e-07, 1.11361e-06,
#         7.45340e-07, 3.18620e-07, 2.95340e-07, 1.00508e-06, 4.06260e-07,
#         2.18827e-06, 1.72595e-06, 2.98690e-07, 9.39440e-07, 2.91430e-07,
#         4.26270e-07, 1.05544e-06, 7.18940e-07, 1.59120e-06, 2.86910e-07,
#         4.02840e-07, 2.08680e-06, 1.46619e-06, 7.01970e-07, 2.81880e-07,
#         4.77830e-06, 3.11560e-07, 2.99760e-07, 1.57951e-06, 4.64325e-06,
#         3.92950e-07, 5.38170e-07, 6.63020e-07, 4.00710e-07, 3.20710e-07,
#         2.32465e-06, 1.04810e-06, 1.38915e-06, 6.76900e-07, 2.15143e-06,
#         5.06090e-07, 4.21770e-07, 2.30201e-06, 4.16300e-07, 6.61330e-07,
#         4.07370e-07, 5.38250e-07, 2.97890e-07, 4.18140e-07, 5.57430e-07,
#         5.11400e-07, 3.02980e-07, 5.58430e-07, 3.92280e-07, 8.84160e-07,
#         4.03230e-07, 4.96580e-07, 2.99970e-07, 2.28631e-06, 3.03530e-07,
#         7.33880e-07]),
#  array([1.66201e-06, 7.49169e-06, 7.73200e-07, 2.76620e-07, 1.19016e-06,
#         6.30130e-07, 7.68410e-07, 7.35770e-07, 1.83400e-07, 4.24450e-07,
#         1.02508e-06, 7.60680e-06, 5.46180e-07, 5.92920e-07, 9.65330e-07,
#         2.05090e-07, 2.07610e-07, 3.53480e-07, 9.32130e-07, 3.44970e-07,
#         1.04819e-06, 6.36820e-07, 8.84240e-07, 6.86110e-07, 1.04456e-06,
#         4.09387e-06, 3.78370e-07, 2.71300e-07, 3.36720e-07, 1.42890e-07,
#         5.79900e-07, 5.28100e-07, 3.75571e-06, 1.06792e-06, 5.19560e-07,
#         7.82070e-07, 1.80102e-06, 6.40650e-07, 5.62410e-07, 4.70870e-07,
#         1.95840e-06, 6.14390e-07, 9.17280e-07, 5.95750e-07, 2.60320e-07,
#         3.83500e-07, 4.17130e-07, 3.88550e-07, 6.49350e-07, 3.89535e-06,
#         9.45990e-07, 8.13970e-07, 5.34160e-07, 1.30341e-06, 8.90520e-07,
#         4.53980e-07, 3.11667e-06, 3.21166e-06, 8.06940e-07, 6.36800e-07,
#         1.27169e-06, 2.53050e-07, 4.23650e-07, 3.15520e-07, 1.20640e-07,
#         5.38040e-06, 4.70183e-06, 1.82695e-06, 2.73472e-06, 9.52330e-07,
#         8.76940e-07, 2.30990e-07, 3.64100e-07, 6.09960e-07, 6.27100e-07,
#         4.45300e-07, 1.32100e-07, 4.46760e-07, 1.30493e-06, 4.22107e-06,
#         3.96890e-07, 6.84910e-07, 1.17712e-06, 1.23900e-06, 5.79440e-07,
#         6.76320e-07, 9.37710e-07, 5.01790e-07, 8.79130e-07, 3.60950e-07,
#         1.47548e-06, 7.35070e-07, 4.27330e-07, 2.37880e-07, 9.53190e-07,
#         7.72820e-07, 4.30050e-07, 4.46330e-07, 5.32080e-07, 1.34508e-06,
#         7.20990e-07, 1.01585e-06, 6.64670e-07, 1.38610e-07, 4.57400e-07,
#         4.32120e-07, 2.46910e-07, 4.27270e-07, 5.86070e-07, 1.04840e-07,
#         9.17400e-08, 4.44150e-07, 3.08040e-07, 6.63980e-07, 1.11770e-07,
#         5.38000e-07, 4.01750e-07, 1.00987e-06, 9.50600e-08, 5.44590e-07,
#         3.27100e-07, 5.46950e-07, 4.14790e-07, 1.25640e-07, 4.33240e-07,
#         1.20460e-07, 7.44400e-07, 1.04642e-06, 4.47530e-07, 3.43140e-07,
#         4.87140e-07, 3.95100e-07, 1.98910e-07, 4.90380e-07, 2.20940e-07,
#         4.62150e-07, 5.33330e-07, 6.12590e-07, 1.77154e-06, 4.23880e-07,
#         1.03510e-07, 5.06690e-07, 4.59410e-07, 5.99300e-07, 1.82800e-07,
#         7.56200e-07, 3.34580e-07, 4.25280e-07, 4.08720e-07, 7.71830e-07,
#         1.55260e-07, 4.54730e-07, 5.31680e-07, 4.99310e-07, 9.91440e-07,
#         4.24200e-07, 1.29580e-07, 2.07540e-07, 4.21500e-07, 4.52140e-07,
#         4.20840e-07, 4.75800e-08, 4.40210e-07, 4.31400e-07, 2.25470e-07,
#         4.38270e-07, 7.49540e-07, 4.63590e-07, 4.20260e-07, 4.13650e-07,
# ...
#         1.30400e-07, 1.22220e-07, 3.02900e-08, 9.01700e-08, 9.94700e-08,
#         8.09900e-08, 8.50700e-08, 1.79660e-07, 8.68800e-08, 9.32500e-08,
#         6.74700e-08, 2.76100e-07, 1.15000e-07, 9.62000e-08, 5.38800e-08,
#         3.16500e-08, 2.66060e-07, 2.84300e-07, 1.83680e-07, 2.44700e-08,
#         4.37780e-07, 3.25500e-08, 5.73100e-08, 6.45300e-08, 3.37610e-07,
#         4.88790e-07, 1.81850e-07, 3.96800e-08, 1.21520e-07, 4.39940e-07,
#         3.26040e-07, 6.51700e-08, 3.14100e-08, 2.66900e-08, 2.58100e-07,
#         5.68800e-08, 3.53420e-07, 3.28590e-07, 5.19300e-08, 3.02990e-07,
#         2.45350e-07, 1.17640e-07, 2.95500e-08, 4.73930e-07, 4.42490e-07,
#         2.31790e-07, 1.71810e-07, 2.92000e-08, 3.85100e-08, 2.73790e-07,
#         2.36460e-07, 1.74480e-07, 3.30430e-07, 4.47750e-07, 3.09040e-07,
#         3.04790e-07, 5.84000e-08, 1.76850e-07, 4.57270e-07, 3.45030e-07,
#         4.35400e-08, 5.86900e-08, 4.50980e-07, 5.82000e-08, 1.21860e-07,
#         5.47100e-08, 4.46290e-07, 1.98880e-07, 4.21050e-07, 2.97500e-08,
#         3.27600e-08, 4.36440e-07, 3.30840e-07, 4.58620e-07, 1.96610e-07,
#         2.73600e-08, 4.50190e-07, 3.85100e-08, 1.95200e-07, 5.52200e-08,
#         3.23200e-08, 2.84040e-07, 4.33290e-07, 2.53060e-07, 5.65100e-08,
#         3.13100e-08, 3.02070e-07, 3.57340e-07, 4.41990e-07, 5.78100e-08,
#         1.11680e-07, 4.80660e-07, 4.38800e-07, 4.52880e-07, 6.37900e-08,
#         4.21300e-08, 4.63980e-07, 4.41110e-07, 1.90210e-07, 4.38270e-07,
#         4.40430e-07, 4.64200e-07, 2.98390e-07, 4.51210e-07, 1.24270e-07,
#         2.97490e-07, 4.46170e-07, 3.12800e-08, 2.44340e-07, 1.75900e-07,
#         2.61800e-08, 2.91210e-07, 6.22400e-08, 1.78460e-07, 3.01660e-07,
#         2.45000e-08, 4.13900e-08, 3.41190e-07, 1.84650e-07, 4.53520e-07,
#         1.26920e-07, 4.43670e-07, 6.38700e-08, 2.38970e-07, 3.07600e-08,
#         6.21500e-08, 4.28410e-07, 4.75660e-07, 1.95120e-07, 3.54600e-07,
#         2.80880e-07, 2.70290e-07]),
#  array([1.85870e-07, 1.78760e-07, 5.90200e-08, 8.24020e-07, 2.09790e-07,
#         7.41300e-08, 1.08160e-07, 7.33130e-07, 1.04790e-07, 1.46132e-06,
#         1.05260e-07, 9.29760e-07, 2.06090e-07, 1.72740e-07, 2.64690e-07,
#         2.29871e-06, 1.48740e-07, 5.51700e-08, 7.04800e-08, 2.23750e-07,
#         6.77500e-08, 7.05200e-08, 1.57010e-07, 7.84860e-07, 5.63700e-08,
#         5.23700e-08, 6.52200e-08, 2.47000e-07, 6.68370e-07, 1.48200e-07,
#         1.66360e-07, 8.80100e-08, 1.16260e-07, 1.54720e-07, 1.59370e-07,
#         9.64700e-08, 6.84000e-08, 1.70300e-07, 6.10000e-08, 1.97040e-07,
#         1.06540e-07, 1.35320e-07, 4.33250e-07, 1.97880e-07, 6.35400e-08,
#         1.24870e-07, 4.76070e-07, 6.93400e-08, 1.10490e-07, 1.28120e-07,
#         1.21690e-07, 2.08370e-07, 4.69820e-07, 1.01190e-07, 1.62090e-07,
#         4.38300e-07, 6.60300e-08, 1.59220e-07, 7.39000e-08, 4.37910e-07,
#         2.06840e-07, 1.32150e-07, 7.01900e-08, 6.28200e-08, 1.64010e-07,
#         6.12400e-08, 1.16940e-07, 1.06400e-07, 1.91900e-07, 1.29910e-07,
#         1.37900e-07, 1.31680e-07, 1.11560e-07, 1.67510e-07, 2.02330e-07,
#         6.63900e-08, 4.54510e-07, 6.72500e-08, 6.43700e-08, 1.34070e-07,
#         1.94500e-07, 4.60060e-07, 1.32560e-07, 6.98100e-08, 9.66000e-08,
#         2.04190e-07, 1.18790e-07, 1.26280e-07, 4.70930e-07, 6.84200e-08,
#         7.28500e-08, 2.04640e-07, 9.28100e-08, 6.27100e-08, 1.00440e-07,
#         1.02260e-07, 1.11990e-07, 6.50800e-08, 1.25490e-07, 1.09480e-07,
#         7.35000e-08, 1.36180e-07, 2.05920e-07, 7.07900e-08, 6.68300e-08,
#         1.90800e-07, 6.63700e-08, 1.10210e-07, 1.00750e-07, 2.08370e-07,
#         6.23500e-08, 1.33830e-07, 6.51200e-08, 1.66720e-07, 7.33900e-08,
#         4.58550e-07, 1.98820e-07, 1.02700e-07, 1.38220e-07, 1.17710e-07,
#         9.48800e-08, 1.31420e-07, 1.34580e-07, 2.05280e-07, 7.07400e-08,
#         1.89640e-07, 1.61800e-07, 4.30590e-07, 1.89870e-07, 6.79200e-08,
#         6.23100e-08, 6.28500e-08, 6.54000e-08, 1.89450e-07, 6.40300e-08,
#         4.57330e-07, 6.88000e-08, 1.98200e-07, 1.03330e-07, 1.04470e-07,
#         1.29130e-07, 9.85600e-08, 7.13300e-08, 1.91610e-07, 1.24130e-07,
#         1.35680e-07, 1.26570e-07, 6.33800e-08, 1.33540e-07, 4.46090e-07,
#         1.04260e-07, 2.04360e-07]),
#  array([1.25512e-06, 9.35490e-07, 2.48123e-06, 1.48244e-06, 4.79720e-07,
#         7.73030e-07, 5.94800e-07, 1.23107e-06, 1.08676e-06, 8.51000e-07,
#         1.39449e-06, 9.94720e-07, 5.71080e-07, 1.71155e-06, 5.84920e-07,
#         1.10815e-06, 9.99510e-07, 5.65480e-07, 8.77840e-07, 4.08990e-07,
#         8.59930e-07, 8.05220e-07, 8.80010e-07, 6.32010e-07, 1.06687e-06,
#         7.45070e-07, 5.23940e-07, 9.10660e-07, 8.86610e-07, 7.44650e-07,
#         1.21199e-06, 1.13213e-06, 3.34910e-07, 1.03709e-06, 6.45920e-07,
#         6.35510e-07, 1.31400e-06, 9.32810e-07, 1.09897e-06, 9.74680e-07,
#         8.84120e-07, 7.92100e-07, 4.26420e-07, 2.72209e-06, 8.78800e-07,
#         5.27260e-07, 1.15257e-06, 7.28900e-07, 9.79220e-07, 9.28170e-07,
#         9.72480e-07, 3.81410e-07, 8.16680e-07, 5.42140e-07, 7.79480e-07,
#         8.27740e-07, 6.11550e-07, 3.08490e-06, 1.00301e-06, 2.41482e-06,
#         1.17797e-06, 8.28450e-07, 1.57672e-06, 8.76270e-07, 1.34837e-06,
#         1.14088e-06, 8.00510e-07, 1.08452e-06, 5.33980e-07, 7.72350e-07,
#         9.64160e-07, 9.31770e-07, 1.22247e-06, 8.49760e-07, 1.18186e-06,
#         8.86990e-07, 8.95800e-07, 4.73110e-07, 5.57820e-07, 1.02319e-06,
#         1.34309e-06, 9.25230e-07, 1.06065e-06, 1.58476e-06, 1.38428e-06,
#         9.12410e-07, 8.68000e-07, 1.88929e-06, 6.62690e-07, 5.57230e-07,
#         7.22540e-07, 7.28540e-07, 9.46880e-07, 8.36960e-07, 8.70120e-07,
#         7.71510e-07, 4.15340e-07, 1.23313e-06, 1.12747e-06, 1.16126e-06,
#         9.99590e-07, 6.28091e-06, 1.31171e-06, 1.26677e-06, 6.75670e-07,
#         1.34595e-06, 8.81530e-07, 1.78144e-06, 8.64090e-07, 6.01460e-07,
#         7.65716e-06, 1.74690e-06, 1.36184e-06, 1.44832e-06, 7.49530e-07,
#         8.79700e-07, 8.62970e-07, 7.63350e-07, 6.81240e-06, 4.28600e-07,
#         8.70740e-07, 1.12142e-06, 1.30729e-06, 1.24424e-06, 1.04331e-06,
#         1.39063e-06, 4.45280e-07, 9.42820e-07, 1.20956e-06, 1.44520e-06,
#         5.76400e-07, 6.46470e-06, 4.35760e-07, 1.57814e-06, 1.33826e-06,
#         1.33078e-06, 9.32500e-07, 7.23140e-07, 1.41329e-06, 6.88600e-07,
#         1.29928e-06, 7.26060e-07, 9.50240e-07, 1.43022e-06, 1.44824e-06,
#         1.48425e-06, 4.23660e-07, 8.55300e-07, 8.14890e-07, 6.14520e-07,
#         1.09617e-06, 6.40390e-07, 1.45681e-06, 9.26880e-07, 6.42566e-06,
#         1.70849e-06, 1.34733e-06, 7.33530e-07, 1.06029e-06, 1.60526e-06,
#         1.44712e-06, 1.31860e-06, 9.81930e-07, 1.74547e-06, 6.28940e-07,
#         1.59622e-06, 1.70327e-06, 9.67230e-07, 9.92840e-07, 1.07653e-06,
#         1.22264e-06, 9.97080e-07, 1.15601e-06, 9.26700e-07, 9.82020e-07,
#         1.72193e-06, 1.49530e-06, 7.39801e-06, 1.16677e-06, 1.15484e-06,
#         1.24938e-06, 1.43687e-06, 7.45590e-07, 9.66040e-07, 6.95960e-07,
#         1.43034e-06, 1.68482e-06, 9.78570e-07, 1.36611e-06, 1.50123e-06,
#         1.37811e-06, 4.78460e-07, 8.67970e-07, 9.19250e-07, 7.43403e-06,
#         1.22524e-06, 7.63600e-07, 9.33350e-07, 8.31900e-07, 4.47290e-07,
#         1.41789e-06, 1.18971e-06, 1.38009e-06, 6.00242e-06, 9.73980e-07,
#         1.07911e-06, 1.18745e-06, 1.34601e-06, 1.08946e-06, 1.06001e-06,
#         8.03510e-07, 1.50307e-06, 1.38727e-06, 1.37118e-06, 1.26002e-06,
#         1.27970e-06, 7.72090e-07, 6.65330e-07, 1.33768e-06, 9.42570e-07,
#         6.34100e-07, 7.72210e-07, 7.84480e-07, 6.60287e-06, 1.67595e-06,
#         1.59351e-06, 1.68235e-06, 8.69010e-07, 9.23290e-07, 9.94740e-07,
#         1.30895e-06, 1.04070e-06, 9.78790e-07, 8.97280e-07, 1.26072e-06,
#         1.33447e-06, 6.38990e-07, 1.12694e-06, 1.27602e-06, 6.88273e-06,
#         7.80440e-07, 1.57717e-06, 1.71581e-06, 6.00388e-06, 5.68340e-07,
#         6.17090e-07, 1.65515e-06, 9.11570e-07, 1.66485e-06, 1.33531e-06,
#         9.20850e-07, 8.68590e-07, 9.14340e-07]),
#  array([3.49520e-07, 3.38500e-07, 3.97490e-07, 3.51490e-07, 3.77820e-07,
#         5.17250e-07, 3.32520e-07, 2.38340e-07, 3.31640e-07, 1.45420e-07,
#         1.30340e-07, 3.32720e-07, 2.15230e-07, 3.33500e-07, 9.26000e-08,
#         1.42500e-07, 3.26060e-07, 1.22410e-07, 1.19320e-07, 9.39600e-08,
#         9.20200e-08, 2.49420e-07, 3.15700e-07, 3.23410e-07, 1.51410e-07,
#         9.80700e-08, 1.94180e-07, 3.18950e-07, 3.44240e-07, 3.45260e-07,
#         1.72670e-07, 3.28670e-07, 3.47140e-07, 2.89450e-07, 8.61000e-08,
#         1.48560e-07, 3.11600e-07, 1.07350e-07, 2.27700e-07, 2.92150e-07,
#         2.03100e-07, 1.68470e-07, 3.22770e-07, 1.77870e-07, 1.18910e-07,
#         1.68190e-07, 3.23630e-07, 1.96890e-07, 1.70370e-07, 1.58590e-07,
#         1.59220e-07, 1.64800e-07, 4.09740e-07, 4.05690e-07, 4.42460e-07,
#         4.52000e-07, 4.70840e-07, 4.07900e-07, 4.80410e-07, 8.06740e-07,
#         4.18730e-07, 4.65480e-07, 4.15690e-07, 3.04290e-07, 2.36060e-07,
#         4.19350e-07, 4.13900e-07, 1.96710e-06, 2.42720e-07, 2.43710e-07,
#         4.77300e-07, 4.10840e-07, 4.30360e-07, 4.26800e-07, 4.08460e-07,
#         1.71170e-07, 3.96160e-07, 2.64730e-07, 4.14730e-07, 2.28940e-07,
#         3.51700e-07, 2.46660e-07, 2.39450e-07, 2.56390e-07, 2.52070e-07,
#         2.93550e-07, 2.51480e-07, 2.60750e-07, 2.78090e-07, 2.37320e-07,
#         2.36940e-07, 2.39360e-07, 2.48990e-07, 2.64200e-07, 2.15970e-07,
#         3.47710e-07, 7.58300e-07, 4.30020e-07, 2.47850e-07, 3.56760e-07,
#         2.48300e-07, 1.54470e-07, 2.41360e-07, 2.55850e-07, 2.41950e-07,
#         1.70390e-07, 2.78470e-07, 2.93610e-07, 1.92400e-07, 2.49730e-07,
#         2.15220e-07, 2.76500e-07, 1.69870e-07, 2.60420e-07, 1.91320e-07,
#         2.99680e-07, 2.97430e-07, 2.59450e-07, 1.90760e-07, 2.37600e-07,
#         2.43210e-07, 1.77390e-07, 2.41260e-07, 3.17650e-07, 2.69510e-07,
#         2.06160e-07, 2.60760e-07, 3.35060e-07, 2.30320e-07, 2.65000e-07,
#         1.78620e-07, 2.29150e-07, 1.48411e-06, 2.98150e-07, 1.76560e-07,
#         2.55170e-07, 2.57970e-07, 2.34420e-07, 2.50570e-07, 2.64390e-07,
#         2.85150e-07, 1.78110e-07, 1.94890e-07, 2.46850e-07, 2.69720e-07,
#         2.59600e-07, 3.19030e-07, 2.39960e-07, 2.65890e-07, 2.03020e-07,
#         2.80570e-07, 2.66440e-07, 1.53630e-07, 3.10040e-07, 4.34230e-07,
#         3.16570e-07, 3.43010e-07, 5.21430e-07, 2.39430e-07, 2.63830e-07,
#         2.35700e-07, 2.99210e-07, 2.51210e-07, 2.38270e-07, 4.21980e-07,
#         2.81550e-07, 2.67320e-07, 3.28510e-07, 2.73490e-07, 2.60290e-07,
#         2.49820e-07, 2.49480e-07, 2.69220e-07, 2.69380e-07, 2.43690e-07,
#         1.92430e-07, 2.73930e-07, 2.35960e-07, 2.66150e-07, 2.66950e-07,
#         2.63320e-07, 2.69910e-07, 2.62510e-07, 2.43060e-07, 2.77590e-07,
#         2.86580e-07, 2.69600e-07, 2.50940e-07, 2.68490e-07, 2.57550e-07,
#         2.65600e-07, 3.11350e-07, 2.48460e-07, 2.79340e-07, 2.40310e-07,
#         2.30030e-07, 2.65290e-07, 2.58170e-07, 2.47800e-07, 2.67710e-07,
#         2.58180e-07, 2.47380e-07, 2.43950e-07, 2.47160e-07, 2.23770e-07,
#         2.39170e-07, 2.76290e-07, 2.39150e-07, 2.48700e-07, 2.54820e-07,
#         3.24550e-07, 3.58100e-07, 2.50250e-07, 2.72350e-07, 1.55420e-07,
#         2.74710e-07, 2.74890e-07, 2.80450e-07, 2.75070e-07, 2.82240e-07,
#         2.63810e-07, 2.71950e-07, 2.56450e-07, 2.66180e-07, 2.89390e-07,
#         2.83150e-07, 2.90050e-07, 2.32180e-07, 4.47060e-07, 2.57650e-07,
#         2.59480e-07, 2.74750e-07, 2.57230e-07, 2.79240e-07, 2.63230e-07,
#         2.69620e-07, 2.63690e-07, 2.97010e-07, 2.58540e-07, 2.62200e-07,
#         2.46530e-07, 5.14000e-07, 2.52240e-07, 2.38580e-07, 2.59430e-07,
#         2.55530e-07, 4.52400e-07, 2.73570e-07, 1.57340e-07, 3.10280e-07,
#         2.74850e-07, 2.75520e-07, 2.22580e-07, 2.54490e-07, 2.55220e-07,
#         2.66440e-07, 2.48070e-07, 2.69210e-07, 2.28320e-07, 2.80420e-07,
#         2.41260e-07, 2.39720e-07, 1.62070e-07, 2.51250e-07, 2.54120e-07,
#         2.82160e-07, 2.61400e-07, 2.40180e-07, 2.82940e-07, 2.96780e-07,
#         2.44750e-07, 2.59980e-07, 2.39150e-07, 2.39920e-07, 2.42780e-07,
#         2.73240e-07, 3.59690e-07, 2.65370e-07, 2.79580e-07, 2.44910e-07,
#         2.66090e-07, 2.44240e-07, 2.40820e-07, 2.68520e-07, 2.46410e-07,
#         1.94850e-07, 2.48900e-07, 2.89760e-07, 5.07030e-07, 2.68460e-07,
#         2.51330e-07, 2.77080e-07, 2.56700e-07, 2.56770e-07, 2.78810e-07,
#         2.37690e-07, 2.55360e-07, 2.76570e-07, 2.43840e-07, 2.51840e-07,
#         2.38540e-07, 2.44060e-07, 2.50590e-07, 2.68890e-07, 2.39730e-07,
#         2.80260e-07, 2.80000e-07, 2.37050e-07, 2.51350e-07, 2.32840e-07,
#         2.78850e-07, 2.78900e-07, 4.37910e-07, 2.40110e-07, 2.66480e-07,
#         2.36480e-07, 3.06110e-07, 2.42430e-07, 2.76650e-07, 2.68960e-07,
#         2.54330e-07, 2.70280e-07, 2.61210e-07, 3.04530e-07, 1.84820e-07,
#         2.78090e-07, 2.55940e-07, 1.53740e-07, 2.45200e-07, 2.68410e-07,
#         2.85100e-07, 2.51960e-07, 2.39280e-07, 2.53600e-07, 2.66280e-07,
#         2.88010e-07, 2.53410e-07, 2.50680e-07, 2.78730e-07, 2.38130e-07,
#         2.42580e-07, 2.47780e-07, 2.58040e-07, 1.89240e-07, 2.64670e-07,
#         2.74350e-07, 2.41570e-07, 1.63120e-07, 2.56630e-07, 3.04030e-07,
#         2.63970e-07, 2.57500e-07, 2.77280e-07, 2.36300e-07, 2.77310e-07,
#         2.45530e-07, 2.80090e-07, 2.31520e-07, 2.58360e-07, 2.71810e-07,
#         3.54160e-07, 2.42420e-07, 2.37200e-07, 1.54420e-07, 2.38940e-07,
#         2.59730e-07, 5.06710e-07, 2.45050e-07, 2.45490e-07, 4.19000e-07,
#         2.56760e-07, 2.44380e-07, 2.73500e-07, 2.59540e-07, 2.41270e-07,
#         2.28110e-07, 2.37020e-07, 3.32950e-07, 2.73220e-07, 3.37090e-07,
#         2.67190e-07, 2.47790e-07, 2.56790e-07, 2.69110e-07, 2.43970e-07,
#         2.74630e-07, 2.33780e-07, 2.69410e-07, 2.41200e-07, 2.52070e-07,
#         2.48280e-07, 2.76770e-07, 2.44860e-07, 2.64090e-07, 2.41920e-07,
#         2.38410e-07, 3.24890e-07, 2.46260e-07, 1.56160e-07, 3.10600e-07,
#         2.89870e-07, 2.52510e-07, 2.46800e-07, 2.56170e-07, 1.57170e-07,
#         2.74500e-07, 2.67280e-07, 5.21290e-07, 2.68490e-07, 2.51000e-07,
#         2.38060e-07, 3.15560e-07, 2.80440e-07, 2.80150e-07, 2.39020e-07,
#         3.34800e-07, 2.39800e-07, 3.17660e-07, 2.38940e-07, 2.57660e-07,
#         2.52670e-07, 2.45840e-07, 2.45990e-07, 2.55680e-07, 2.51630e-07,
#         2.60080e-07, 3.04350e-07, 2.66490e-07, 3.02560e-07, 2.46060e-07,
#         4.96020e-07, 2.71260e-07, 2.76560e-07, 2.46850e-07, 2.36700e-07,
#         2.41670e-07, 2.64450e-07, 2.42370e-07, 2.63560e-07, 2.46610e-07,
#         2.43710e-07, 2.54050e-07, 2.39580e-07, 2.42610e-07, 2.36870e-07,
#         2.56210e-07, 2.72420e-07, 2.99010e-07, 3.14940e-07, 2.58760e-07,
#         1.84940e-07, 4.13780e-07, 4.44410e-07, 2.44460e-07, 2.61590e-07,
#         2.79810e-07, 2.39260e-07, 1.89570e-07, 2.39420e-07, 2.74110e-07,
#         2.78900e-07, 2.58430e-07, 2.64100e-07, 2.41510e-07, 2.91630e-07,
#         2.38870e-07, 3.13780e-07, 2.81050e-07, 2.41700e-07, 2.78040e-07,
#         2.37870e-07, 2.45830e-07, 4.37690e-07, 2.49760e-07, 2.47690e-07,
#         2.51730e-07, 2.80280e-07, 2.96520e-07, 2.60280e-07, 2.74530e-07,
#         2.42330e-07, 2.47090e-07, 3.05790e-07, 4.37100e-07, 2.85530e-07,
#         2.43920e-07, 4.41660e-07, 2.41480e-07, 2.36680e-07, 3.13230e-07,
#         2.78770e-07, 2.45280e-07, 2.45870e-07, 2.78150e-07, 2.48170e-07,
#         4.21840e-07, 2.44200e-07, 2.44260e-07, 3.03120e-07, 2.58830e-07,
#         2.80860e-07, 3.54630e-07, 3.00740e-07, 4.46010e-07, 2.63010e-07,
#         2.69140e-07, 2.37250e-07, 2.61780e-07, 2.82820e-07, 2.66930e-07,
#         2.64350e-07, 2.61280e-07, 2.78120e-07, 2.79180e-07, 2.75510e-07,
#         2.67770e-07, 2.72660e-07, 2.39030e-07, 3.23280e-07, 2.45520e-07,
#         2.39110e-07, 2.46360e-07, 4.20380e-07, 2.66030e-07, 2.53960e-07,
#         2.57560e-07, 2.70780e-07, 2.56560e-07, 2.65140e-07, 2.46680e-07,
#         3.14060e-07, 2.56110e-07, 2.57070e-07, 2.41180e-07, 2.70550e-07,
#         2.71410e-07, 2.87380e-07, 2.43710e-07, 2.72310e-07, 2.61670e-07,
#         2.43460e-07, 2.59940e-07, 4.11980e-07, 2.78710e-07, 2.72690e-07,
#         3.10170e-07, 2.29590e-07, 3.16540e-07, 2.65980e-07, 2.63850e-07,
#         4.59200e-07, 3.56870e-07, 2.52600e-07, 2.67990e-07, 3.18300e-07,
#         3.01400e-07, 2.80340e-07])]

# %%
## The observing baseline for each pulsar (in years)
tspans = np.array([(psr.toas.max() - psr.toas.min())/(86400 * 365.25) for psr in psrs])
tspans
# Out:
# array([19.61553951, 19.88386037, 13.07961551, 13.04387035, 19.51900011,
#        12.51381619, 19.36585837, 10.62819041, 13.19077171, 10.6564222 ,
#        11.41969619, 20.05824211, 14.82634518, 10.65891428, 11.03925762,
#        20.06141982, 16.7728371 , 15.88548734, 19.44448269, 19.83396916,
#        19.51772217, 14.75459153, 13.05150141, 20.03885741, 12.48657664,
#        11.45566901, 13.14618083, 14.77047734, 19.80923585, 15.45826023,
#        11.05251678, 19.80513002, 12.97354426, 16.58489963, 14.88651998,
#        12.44574529, 10.99226326, 13.07301331, 19.87300691, 12.83711162,
#        11.05023234, 10.57382013, 11.15134373, 12.48551647, 19.61854761])

# %% [markdown]
# ## <span style="color:#7cfc00"> Noise Modeling Using ENTERPRISE

# %% [markdown]
# $\Large R(t) = M \epsilon + Fa + \text{WN} $

# %% [markdown]
# ### <span style="color:#7cfc00"> Timing Model

# %% [markdown]
# When we construct a timing model for a pulsar, we have uncertainties about our model. This uncertainty $\epsilon$ needs to be taken into consideration in any noise modeling that we do.
# The matrix $M$ is the design-matrix containing the bases of the timing model parameters.

# %%
tm = gp_signals.MarginalizingTimingModel(use_svd=True)

# %% [markdown]
# ### <span style="color:#7cfc00"> White Noise

# %%
## Do you need to vary the parameters that describe white noise (EFAC, EQUAD, and ECORR are the params)?
vary = False
if not vary:
    noise_dict = {}
    for pname in psrlist:
        noise_dict.update({pname + '_efac': 1.0})
        noise_dict.update({pname + '_log10_t2equad': -np.inf})
## Do you need to include ECORR noise (do not worry if you do not know what ECORR is!)?
inc_ecorr = False
## Do you want to use different backends for the telescopes?
select = 'none'

wn = blocks.white_noise_block(vary = vary, inc_ecorr = inc_ecorr, select = select)

# %% [markdown]
# ### <span style="color:#7cfc00"> Intrinsic Red Noise

# %%
## How do you want to model the spectral power of your red noise? 
psd = 'powerlaw'
## What do you know about the prior for the parameters that describe the red noise?
prior = 'log-uniform'
## What frequencies do you want to consider in your model? It must be in seconds.
number_of_bins = 30
observing_time_to_use_in_freq_calculation = tspans.max() * 86400 * 365.25

rn = blocks.red_noise_block(psd=psd, prior=prior, Tspan=observing_time_to_use_in_freq_calculation,
                            components=number_of_bins)

# %% [markdown]
# ### <span style="color:#7cfc00">Common Red Noise

# %%
## How do you want to model the spectral power of your red noise? 
psd = 'powerlaw'
## What do you know about the prior for the parameters that describe the red noise?
prior = 'log-uniform'
## What frequencies do you want to consider in your model? It must be in seconds.
number_of_bins = 5
observing_time_to_use_in_freq_calculation = tspans.max() * 86400 * 365.25

crn = blocks.common_red_noise_block(psd=psd, prior=prior, 
                                    Tspan=observing_time_to_use_in_freq_calculation, 
                                    components=number_of_bins,
                                    name = 'crn')

# %% [markdown]
# ### <span style="color:#7cfc00">Common Correlated Red Noise

# %%
## How do you want to model the spectral power of your red noise? 
psd = 'powerlaw'
## What do you know about the prior for the parameters that describe the red noise?
prior = 'log-uniform'
## What frequencies do you want to consider in your model? It must be in seconds.
number_of_bins = 5
observing_time_to_use_in_freq_calculation = tspans.max() * 86400 * 365.25
## What functional shape do you want the correlations to follow?
corr = 'hd'

ccrn = blocks.common_red_noise_block(psd=psd, prior=prior, 
                                    Tspan=observing_time_to_use_in_freq_calculation, 
                                    components=number_of_bins, orf = corr,
                                    name = 'gw')

# %% [markdown]
# ### <span style="color:#7cfc00">Build the Model

# %%
#signal = tm + wn + rn
#signal = tm + wn + crn
#signal = tm + wn + ccrn
signal = tm + wn + rn + crn

# %%
## How many pulsars do you want to consider in your model?
psrs_to_choose = psrs[:]
## Build the model
pta = signal_base.PTA([signal(p) for p in psrs_to_choose], lnlikelihood = signal_base.LogLikelihoodDenseCholesky)
## You need to fix the white noise parameters if you chose not to vary them when defining `wn`
if not vary:
    pta.set_default_params(noise_dict)

# %%
pta.params
# Out:
# [B1855+09_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  B1855+09_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  B1937+21_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  B1937+21_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  B1953+29_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  B1953+29_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0023+0923_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0023+0923_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0030+0451_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0030+0451_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0340+4130_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0340+4130_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0613-0200_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0613-0200_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0636+5128_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0636+5128_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0645+5158_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0645+5158_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0740+6620_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0740+6620_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J0931-1902_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J0931-1902_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1012+5307_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1012+5307_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1024-0719_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1024-0719_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1125+7819_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1125+7819_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1453+1902_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1453+1902_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1455-3330_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1455-3330_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1600-3053_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1600-3053_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1614-2230_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1614-2230_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1640+2224_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1640+2224_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1643-1224_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1643-1224_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1713+0747_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1713+0747_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1738+0333_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1738+0333_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1741+1351_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1741+1351_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1744-1134_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1744-1134_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1747-4036_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1747-4036_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1832-0836_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1832-0836_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1853+1303_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1853+1303_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1903+0327_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1903+0327_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1909-3744_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1909-3744_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1910+1256_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1910+1256_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1911+1347_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1911+1347_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1918-0642_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1918-0642_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1923+2515_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1923+2515_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J1944+0907_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J1944+0907_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2010-1323_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2010-1323_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2017+0603_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2017+0603_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2033+1734_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2033+1734_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2043+1711_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2043+1711_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2145-0750_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2145-0750_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2214+3000_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2214+3000_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2229+2643_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2229+2643_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2234+0611_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2234+0611_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2234+0944_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2234+0944_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2302+4442_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2302+4442_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  J2317+1439_red_noise_gamma:Uniform(pmin=0, pmax=7),
#  J2317+1439_red_noise_log10_A:Uniform(pmin=-20, pmax=-11),
#  crn_gamma:Uniform(pmin=0, pmax=7),
#  crn_log10_A:Uniform(pmin=-18, pmax=-11)]

# %% [markdown]
# ### <span style="color:#7cfc00">Calculate the log-liklihood of the model

# %%
x0 = np.hstack([p.sample() for p in pta.params])
pta.get_lnlikelihood(x0)
# Out:
# KernelMatrix(153515.09605919)

# %% [markdown]
# # <span style="color:#7cfc00"> MCMC Sampler

# %%
## Output directory
outdir = '../Chain/Fall/MCMC'

## Jump Proposals, groups, and MCMC Tunings
ndim = len(x0)
cov = np.diag(np.ones(ndim) * 0.01**2) # helps to tune MCMC proposal distribution

pars = pta.param_names
idx_orf_params0 = [list(pars).index(pp) for pp in pars if 'crn' in pp]
groups = [list(np.arange(0, ndim))]
[groups.append(idx_orf_params0) for ii in range(5)]

## Initiate the sampler
sampler = ptmcmc(ndim, pta.get_lnlikelihood, pta.get_lnprior, cov, groups = groups,
                 outDir=outdir, 
                 resume=False)

jp = samp.JumpProposal(pta)
sampler.addProposalToCycle(jp.draw_from_prior, 15)
sampler.addProposalToCycle(jp.draw_from_red_prior, 15)

## Number of MCMC steps
N = int(1e5)

# %%
#sampler.sample(x0, N, SCAMweight=30, AMweight=15, DEweight=50, )

# %% [markdown]
# ## <span style="color:#7cfc00">Post-proccessing the output of MCMC

# %%
# chain = np.loadtxt(outdir + '/chain_1.txt')
# burn = int(0.25 * chain.shape[0])
# chain = chain[burn:, :]
# chain.shape

# %%
# for p, d in zip(pta.param_names, chain[:, :-4].T):
#     plt.hist(d, **hist_settings)
#     plt.title(p)
#     plt.xlabel('Paramter Value')
#     plt.ylabel('Count')
#     plt.show()

# %% [markdown]
# # <span style="color:#7cfc00">Detection Practice Outside ENTERPRISE

# %% [markdown]
# ## <span style="color:#7cfc00"> Simulate a Simple PTA Data Set

# %%
Npulsars = 5        ##number of pulsars
observ_time = 20    ##years
start_time = 5300   ##mjd
cadence = 14        ##days
Nrea = 10           ##number of realizations
toas = np.array([np.arange(start_time, start_time + observ_time * 365.25, cadence) for _ in range(Npulsars)])

wn_sig = 1e-7       ##white_noise level in seconds
gwb_amplitude = 2e-15
gwb_alpha = -2/3

# %%
lam, bet, pnames, locs = sim.UniformPulsarDist(Numpulsars=Npulsars, name =True)

# %%
s = sim.PTASIM(MG = 'TT', 
                    psrlist = pnames,
                    toas = toas,
                    psr_locs = locs.T, 
                    Amp = np.array([gwb_amplitude]),
                    alpha = np.array([gwb_alpha]), 
                    wn_sig = wn_sig,
                    Nrea = Nrea,
                    seed = 15645789)

# %%
gw_res = s.total_res()

# %%
pidx = 3
rea = 2

plt.plot(toas[pidx], gw_res[rea][pidx])
plt.title(pnames[pidx])
plt.xlabel('TOAS [MJD]')
plt.ylabel('Residuals [s]')
plt.show()

# %% [markdown]
# ## <span style="color:#7cfc00">Single-pulsar Ananlysis Using Gibbs Sampling

# %%
crn_bins = 5
Gsamples = int(1e4)

# %%
BP = nc.BayesPower(nc.Nimapta(gw_res[rea][pidx], 
                        toas = toas[pidx], 
                        fit = False, 
                        psr_pos = locs[:, pidx],
                        wn_sigma = wn_sig),

                            red_amp = None,
                            red_gamma = None,
                            crn_bins = crn_bins,
                            Baseline = observ_time,
                            inj_amp = gwb_amplitude,
                            gamma = -1 * (2 * gwb_alpha - 3),
                            num_samples = Gsamples)

# %%
_, rho = BP.gibbs_sampler(progress = True)
# Out:
# 100%|██████████| 10000/10000 [00:18<00:00, 536.58it/s]

# %%
labs = [r'$\rho_{{{0}}}$'.format(_) for _ in range(1, crn_bins + 1)]
labs
# Out:
# ['$\\rho_{1}$', '$\\rho_{2}$', '$\\rho_{3}$', '$\\rho_{4}$', '$\\rho_{5}$']

# %% [markdown]
# ## <span style="color:#7cfc00">Results

# %%
corner.corner(rho.T, color='gold', bins=20, hist_bin_factor=2, hist_kwargs={'density': True, 'lw':2}, 
              contour_kwargs={'linewidths':2}, labels = labs, quantile = True,show_titles = True,
              truth_color = 'white', desity = True, truths = BP.truth())
plt.show()

# %% [markdown]
# Make sure you know why the above plot looks how it looks!
